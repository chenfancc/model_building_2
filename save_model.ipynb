# %%
from function import *
from model_trainer import TrainModel
import numpy as np
from model import *
from function import plot_info

BATCH_SIZE = 512
EPOCH = 100
LR = 0.01 # 5e-6
GAMMA = 0.95
STEP_SIZE = 20  # 每隔多少个 epoch 衰减一次学习率
DECAY = 1e-4
DEVICE = "cuda"
SEED = 42
ALPHA_LOSS = 1
GAMMA_LOSS = 3

hyperparameters = {
    "BATCH_SIZE": BATCH_SIZE,
    "EPOCH": EPOCH,
    "LEARNING_RATE": LR,
    "GAMMA": GAMMA,
    "STEP_SIZE": STEP_SIZE,
    "DECAY": DECAY,
    "device": DEVICE,
    "SEED": SEED,
    "ALPHA_LOSS": ALPHA_LOSS,
    "GAMMA_LOSS": GAMMA_LOSS
}

# 设置随机种子
np.random.seed(SEED)
torch.manual_seed(SEED)

for SAMPLE_METHOD in ["undersample"]:
    for model in [BiLSTM, BiLSTM_BN]:
        tensor_direction = f'E:\deeplearning\Zhongda\zyy_tensor.pth'
        train_dataloader, val_dataloader, test_dataloader = main_data_loader(tensor_direction, SAMPLE_METHOD, BATCH_SIZE)
        model_name = f"ZYY_{model.__name__}_model_{SAMPLE_METHOD}_FocalLoss_{EPOCH}_{LR}"
        loss_f = FocalLoss(ALPHA_LOSS, GAMMA_LOSS)
        trainer = TrainModel(model_name, model, hyperparameters, train_dataloader, val_dataloader,
                             criterion_class=loss_f, root_dir='ZYY', save_model_index=[21, 57])
        info = trainer.train()
        # trainer.save_model()
        # plot_info(info, model_name, root_dir='ZYY')
# Out:
# ---------------------------------------Epoch: 1---------------------------------------
# Epoch 1, Train Loss: 0.0769
# 整体验证集上的Loss: 0.10601055158998349
# AUROC: 0.6569
# Best threshold: 0.1145
# AUPRC: 0.1318
# Best threshold: 0.1524
# auc
# Confusion Matrix:
# [[8605 3961]
#  [ 402  486]]
# Specificity: 0.6848
# Sensitivity: 0.5473
# Alarm Accuracy: 0.1093
# Accuracy: 0.6757
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11566  1000]
#  [  661   227]]
# Specificity: 0.9204
# Sensitivity: 0.2556
# Alarm Accuracy: 0.1850
# Accuracy: 0.8765
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 2---------------------------------------
# Epoch 2, Train Loss: 0.0764
# 整体验证集上的Loss: 0.14667340015308947
# AUROC: 0.5629
# Best threshold: 0.3877
# AUPRC: 0.1145
# Best threshold: 0.3969
# auc
# Confusion Matrix:
# [[10668  1898]
#  [  588   300]]
# Specificity: 0.8490
# Sensitivity: 0.3378
# Alarm Accuracy: 0.1365
# Accuracy: 0.8152
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10904  1662]
#  [  610   278]]
# Specificity: 0.8677
# Sensitivity: 0.3131
# Alarm Accuracy: 0.1433
# Accuracy: 0.8311
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 3---------------------------------------
# Epoch 3, Train Loss: 0.0766
# 整体验证集上的Loss: 0.3077928562456061
# AUROC: 0.5664
# Best threshold: 0.7994
# AUPRC: 0.1202
# Best threshold: 0.8240
# auc
# Confusion Matrix:
# [[10560  2006]
#  [  579   309]]
# Specificity: 0.8404
# Sensitivity: 0.3480
# Alarm Accuracy: 0.1335
# Accuracy: 0.8079
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11114  1452]
#  [  632   256]]
# Specificity: 0.8845
# Sensitivity: 0.2883
# Alarm Accuracy: 0.1499
# Accuracy: 0.8451
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 4---------------------------------------
# Epoch 4, Train Loss: 0.0748
# 整体验证集上的Loss: 0.10437403680487033
# AUROC: 0.5473
# Best threshold: 0.1610
# AUPRC: 0.1079
# Best threshold: 0.1838
# auc
# Confusion Matrix:
# [[10704  1862]
#  [  575   313]]
# Specificity: 0.8518
# Sensitivity: 0.3525
# Alarm Accuracy: 0.1439
# Accuracy: 0.8189
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10817  1749]
#  [  584   304]]
# Specificity: 0.8608
# Sensitivity: 0.3423
# Alarm Accuracy: 0.1481
# Accuracy: 0.8266
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 5---------------------------------------
# Epoch 5, Train Loss: 0.0759
# 整体验证集上的Loss: 0.18612586243774273
# AUROC: 0.5663
# Best threshold: 0.6495
# AUPRC: 0.1232
# Best threshold: 0.7133
# auc
# Confusion Matrix:
# [[9821 2745]
#  [ 525  363]]
# Specificity: 0.7816
# Sensitivity: 0.4088
# Alarm Accuracy: 0.1168
# Accuracy: 0.7569
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10673  1893]
#  [  594   294]]
# Specificity: 0.8494
# Sensitivity: 0.3311
# Alarm Accuracy: 0.1344
# Accuracy: 0.8151
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 6---------------------------------------
# Epoch 6, Train Loss: 0.0761
# 整体验证集上的Loss: 0.17376181268518942
# AUROC: 0.5621
# Best threshold: 0.6592
# AUPRC: 0.1181
# Best threshold: 0.6864
# auc
# Confusion Matrix:
# [[10493  2073]
#  [  557   331]]
# Specificity: 0.8350
# Sensitivity: 0.3727
# Alarm Accuracy: 0.1377
# Accuracy: 0.8045
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10772  1794]
#  [  582   306]]
# Specificity: 0.8572
# Sensitivity: 0.3446
# Alarm Accuracy: 0.1457
# Accuracy: 0.8234
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 7---------------------------------------
# Epoch 7, Train Loss: 0.0756
# 整体验证集上的Loss: 0.10410770228000923
# AUROC: 0.5557
# Best threshold: 0.0881
# AUPRC: 0.1137
# Best threshold: 0.1186
# auc
# Confusion Matrix:
# [[10612  1954]
#  [  562   326]]
# Specificity: 0.8445
# Sensitivity: 0.3671
# Alarm Accuracy: 0.1430
# Accuracy: 0.8130
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10894  1672]
#  [  585   303]]
# Specificity: 0.8669
# Sensitivity: 0.3412
# Alarm Accuracy: 0.1534
# Accuracy: 0.8322
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 8---------------------------------------
# Epoch 8, Train Loss: 0.0745
# 整体验证集上的Loss: 0.15376462765803162
# AUROC: 0.5796
# Best threshold: 0.5092
# AUPRC: 0.1206
# Best threshold: 0.5447
# auc
# Confusion Matrix:
# [[10689  1877]
#  [  574   314]]
# Specificity: 0.8506
# Sensitivity: 0.3536
# Alarm Accuracy: 0.1433
# Accuracy: 0.8178
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10944  1622]
#  [  599   289]]
# Specificity: 0.8709
# Sensitivity: 0.3255
# Alarm Accuracy: 0.1512
# Accuracy: 0.8349
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 9---------------------------------------
# Epoch 9, Train Loss: 0.0760
# 整体验证集上的Loss: 0.12996176111966593
# AUROC: 0.5478
# Best threshold: 0.2968
# AUPRC: 0.1067
# Best threshold: 0.4613
# auc
# Confusion Matrix:
# [[10124  2442]
#  [  559   329]]
# Specificity: 0.8057
# Sensitivity: 0.3705
# Alarm Accuracy: 0.1187
# Accuracy: 0.7769
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11384  1182]
#  [  677   211]]
# Specificity: 0.9059
# Sensitivity: 0.2376
# Alarm Accuracy: 0.1515
# Accuracy: 0.8618
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 10---------------------------------------
# Epoch 10, Train Loss: 0.0772
# 整体验证集上的Loss: 0.10320259719472462
# AUROC: 0.5552
# Best threshold: 0.0203
# AUPRC: 0.1108
# Best threshold: 0.0237
# auc
# Confusion Matrix:
# [[10618  1948]
#  [  562   326]]
# Specificity: 0.8450
# Sensitivity: 0.3671
# Alarm Accuracy: 0.1434
# Accuracy: 0.8134
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10668  1898]
#  [  566   322]]
# Specificity: 0.8490
# Sensitivity: 0.3626
# Alarm Accuracy: 0.1450
# Accuracy: 0.8169
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 11---------------------------------------
# Epoch 11, Train Loss: 0.0774
# 整体验证集上的Loss: 0.14326965318171184
# AUROC: 0.5839
# Best threshold: 0.5883
# AUPRC: 0.1195
# Best threshold: 0.5903
# auc
# Confusion Matrix:
# [[10701  1865]
#  [  565   323]]
# Specificity: 0.8516
# Sensitivity: 0.3637
# Alarm Accuracy: 0.1476
# Accuracy: 0.8194
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10710  1856]
#  [  566   322]]
# Specificity: 0.8523
# Sensitivity: 0.3626
# Alarm Accuracy: 0.1478
# Accuracy: 0.8200
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 12---------------------------------------
# Epoch 12, Train Loss: 0.0791
# 整体验证集上的Loss: 0.08664193865814916
# AUROC: 0.5449
# Best threshold: 0.0000
# AUPRC: 0.1122
# Best threshold: 0.0000
# auc
# Confusion Matrix:
# [[10039  2527]
#  [  545   343]]
# Specificity: 0.7989
# Sensitivity: 0.3863
# Alarm Accuracy: 0.1195
# Accuracy: 0.7717
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11031  1535]
#  [  638   250]]
# Specificity: 0.8778
# Sensitivity: 0.2815
# Alarm Accuracy: 0.1401
# Accuracy: 0.8385
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 13---------------------------------------
# Epoch 13, Train Loss: 0.0756
# 整体验证集上的Loss: 0.10063994019609028
# AUROC: 0.5669
# Best threshold: 0.0040
# AUPRC: 0.1159
# Best threshold: 0.0169
# auc
# Confusion Matrix:
# [[10205  2361]
#  [  546   342]]
# Specificity: 0.8121
# Sensitivity: 0.3851
# Alarm Accuracy: 0.1265
# Accuracy: 0.7839
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10860  1706]
#  [  601   287]]
# Specificity: 0.8642
# Sensitivity: 0.3232
# Alarm Accuracy: 0.1440
# Accuracy: 0.8285
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 14---------------------------------------
# Epoch 14, Train Loss: 0.0775
# 整体验证集上的Loss: 0.08801744139242172
# AUROC: 0.5650
# Best threshold: 0.0011
# AUPRC: 0.1174
# Best threshold: 0.0019
# auc
# Confusion Matrix:
# [[10319  2247]
#  [  553   335]]
# Specificity: 0.8212
# Sensitivity: 0.3773
# Alarm Accuracy: 0.1297
# Accuracy: 0.7919
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10737  1829]
#  [  590   298]]
# Specificity: 0.8544
# Sensitivity: 0.3356
# Alarm Accuracy: 0.1401
# Accuracy: 0.8202
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 15---------------------------------------
# Epoch 15, Train Loss: 0.0776
# 整体验证集上的Loss: 0.16203236917040084
# AUROC: 0.5381
# Best threshold: 0.6281
# AUPRC: 0.1148
# Best threshold: 0.6386
# auc
# Confusion Matrix:
# [[10875  1691]
#  [  610   278]]
# Specificity: 0.8654
# Sensitivity: 0.3131
# Alarm Accuracy: 0.1412
# Accuracy: 0.8290
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11002  1564]
#  [  620   268]]
# Specificity: 0.8755
# Sensitivity: 0.3018
# Alarm Accuracy: 0.1463
# Accuracy: 0.8377
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 16---------------------------------------
# Epoch 16, Train Loss: 0.0748
# 整体验证集上的Loss: 0.09503274030644805
# AUROC: 0.5570
# Best threshold: 0.0362
# AUPRC: 0.1151
# Best threshold: 0.0389
# auc
# Confusion Matrix:
# [[10567  1999]
#  [  573   315]]
# Specificity: 0.8409
# Sensitivity: 0.3547
# Alarm Accuracy: 0.1361
# Accuracy: 0.8088
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10632  1934]
#  [  578   310]]
# Specificity: 0.8461
# Sensitivity: 0.3491
# Alarm Accuracy: 0.1381
# Accuracy: 0.8133
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 17---------------------------------------
# Epoch 17, Train Loss: 0.0775
# 整体验证集上的Loss: 0.2447473661264137
# AUROC: 0.5361
# Best threshold: 0.8330
# AUPRC: 0.1080
# Best threshold: 0.8337
# auc
# Confusion Matrix:
# [[10551  2015]
#  [  561   327]]
# Specificity: 0.8396
# Sensitivity: 0.3682
# Alarm Accuracy: 0.1396
# Accuracy: 0.8085
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10560  2006]
#  [  562   326]]
# Specificity: 0.8404
# Sensitivity: 0.3671
# Alarm Accuracy: 0.1398
# Accuracy: 0.8091
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 18---------------------------------------
# Epoch 18, Train Loss: 0.0812
# 整体验证集上的Loss: 0.09091618331983355
# AUROC: 0.5665
# Best threshold: 0.0008
# AUPRC: 0.1174
# Best threshold: 0.0010
# auc
# Confusion Matrix:
# [[10617  1949]
#  [  560   328]]
# Specificity: 0.8449
# Sensitivity: 0.3694
# Alarm Accuracy: 0.1440
# Accuracy: 0.8135
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10719  1847]
#  [  571   317]]
# Specificity: 0.8530
# Sensitivity: 0.3570
# Alarm Accuracy: 0.1465
# Accuracy: 0.8203
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 19---------------------------------------
# Epoch 19, Train Loss: 0.0780
# 整体验证集上的Loss: 0.09441936767148972
# AUROC: 0.5555
# Best threshold: 0.0677
# AUPRC: 0.1141
# Best threshold: 0.0730
# auc
# Confusion Matrix:
# [[10654  1912]
#  [  581   307]]
# Specificity: 0.8478
# Sensitivity: 0.3457
# Alarm Accuracy: 0.1384
# Accuracy: 0.8147
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10766  1800]
#  [  593   295]]
# Specificity: 0.8568
# Sensitivity: 0.3322
# Alarm Accuracy: 0.1408
# Accuracy: 0.8221
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 20---------------------------------------
# Epoch 20, Train Loss: 0.0784
# 整体验证集上的Loss: 0.20552674217845776
# AUROC: 0.5808
# Best threshold: 0.6316
# AUPRC: 0.1192
# Best threshold: 0.6316
# auc
# Confusion Matrix:
# [[10739  1827]
#  [  565   323]]
# Specificity: 0.8546
# Sensitivity: 0.3637
# Alarm Accuracy: 0.1502
# Accuracy: 0.8222
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10739  1827]
#  [  565   323]]
# Specificity: 0.8546
# Sensitivity: 0.3637
# Alarm Accuracy: 0.1502
# Accuracy: 0.8222
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 21---------------------------------------
# Epoch 21, Train Loss: 0.0774
# Model has been saved into: model_saved_dir
# 整体验证集上的Loss: 0.1277280847832362
# AUROC: 0.5627
# Best threshold: 0.2555
# AUPRC: 0.1168
# Best threshold: 0.2680
# auc
# Confusion Matrix:
# [[10551  2015]
#  [  557   331]]
# Specificity: 0.8396
# Sensitivity: 0.3727
# Alarm Accuracy: 0.1411
# Accuracy: 0.8088
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10633  1933]
#  [  564   324]]
# Specificity: 0.8462
# Sensitivity: 0.3649
# Alarm Accuracy: 0.1436
# Accuracy: 0.8144
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 22---------------------------------------
# Epoch 22, Train Loss: 0.0801
# 整体验证集上的Loss: 0.08740363414026191
# AUROC: 0.5525
# Best threshold: 0.0010
# AUPRC: 0.1136
# Best threshold: 0.0029
# auc
# Confusion Matrix:
# [[10276  2290]
#  [  561   327]]
# Specificity: 0.8178
# Sensitivity: 0.3682
# Alarm Accuracy: 0.1250
# Accuracy: 0.7881
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11205  1361]
#  [  652   236]]
# Specificity: 0.8917
# Sensitivity: 0.2658
# Alarm Accuracy: 0.1478
# Accuracy: 0.8504
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 23---------------------------------------
# Epoch 23, Train Loss: 0.0810
# 整体验证集上的Loss: 0.1180344232855373
# AUROC: 0.5738
# Best threshold: 0.2718
# AUPRC: 0.1199
# Best threshold: 0.2815
# auc
# Confusion Matrix:
# [[10649  1917]
#  [  560   328]]
# Specificity: 0.8474
# Sensitivity: 0.3694
# Alarm Accuracy: 0.1461
# Accuracy: 0.8159
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10739  1827]
#  [  568   320]]
# Specificity: 0.8546
# Sensitivity: 0.3604
# Alarm Accuracy: 0.1490
# Accuracy: 0.8220
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 24---------------------------------------
# Epoch 24, Train Loss: 0.0758
# 整体验证集上的Loss: 0.08858125110956475
# AUROC: 0.5632
# Best threshold: 0.0000
# AUPRC: 0.1135
# Best threshold: 0.0000
# auc
# Confusion Matrix:
# [[10650  1916]
#  [  569   319]]
# Specificity: 0.8475
# Sensitivity: 0.3592
# Alarm Accuracy: 0.1427
# Accuracy: 0.8153
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10690  1876]
#  [  573   315]]
# Specificity: 0.8507
# Sensitivity: 0.3547
# Alarm Accuracy: 0.1438
# Accuracy: 0.8180
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 25---------------------------------------
# Epoch 25, Train Loss: 0.0768
# 整体验证集上的Loss: 0.09927063910434865
# AUROC: 0.5763
# Best threshold: 0.1074
# AUPRC: 0.1160
# Best threshold: 0.1346
# auc
# Confusion Matrix:
# [[10466  2100]
#  [  558   330]]
# Specificity: 0.8329
# Sensitivity: 0.3716
# Alarm Accuracy: 0.1358
# Accuracy: 0.8024
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10741  1825]
#  [  585   303]]
# Specificity: 0.8548
# Sensitivity: 0.3412
# Alarm Accuracy: 0.1424
# Accuracy: 0.8209
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 26---------------------------------------
# Epoch 26, Train Loss: 0.0756
# 整体验证集上的Loss: 0.1025529984571669
# AUROC: 0.5621
# Best threshold: 0.0947
# AUPRC: 0.1172
# Best threshold: 0.1184
# auc
# Confusion Matrix:
# [[10610  1956]
#  [  557   331]]
# Specificity: 0.8443
# Sensitivity: 0.3727
# Alarm Accuracy: 0.1447
# Accuracy: 0.8132
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10739  1827]
#  [  571   317]]
# Specificity: 0.8546
# Sensitivity: 0.3570
# Alarm Accuracy: 0.1479
# Accuracy: 0.8218
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 27---------------------------------------
# Epoch 27, Train Loss: 0.0768
# 整体验证集上的Loss: 0.09376725063769023
# AUROC: 0.5644
# Best threshold: 0.0013
# AUPRC: 0.1129
# Best threshold: 0.0023
# auc
# Confusion Matrix:
# [[10617  1949]
#  [  564   324]]
# Specificity: 0.8449
# Sensitivity: 0.3649
# Alarm Accuracy: 0.1425
# Accuracy: 0.8132
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10828  1738]
#  [  582   306]]
# Specificity: 0.8617
# Sensitivity: 0.3446
# Alarm Accuracy: 0.1497
# Accuracy: 0.8276
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 28---------------------------------------
# Epoch 28, Train Loss: 0.0784
# 整体验证集上的Loss: 0.11859664630496061
# AUROC: 0.5422
# Best threshold: 0.2347
# AUPRC: 0.1137
# Best threshold: 0.2347
# auc
# Confusion Matrix:
# [[10585  1981]
#  [  563   325]]
# Specificity: 0.8424
# Sensitivity: 0.3660
# Alarm Accuracy: 0.1409
# Accuracy: 0.8109
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10585  1981]
#  [  563   325]]
# Specificity: 0.8424
# Sensitivity: 0.3660
# Alarm Accuracy: 0.1409
# Accuracy: 0.8109
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 29---------------------------------------
# Epoch 29, Train Loss: 0.0762
# 整体验证集上的Loss: 0.09762293520286348
# AUROC: 0.6005
# Best threshold: 0.0542
# AUPRC: 0.1190
# Best threshold: 0.1208
# auc
# Confusion Matrix:
# [[10211  2355]
#  [  538   350]]
# Specificity: 0.8126
# Sensitivity: 0.3941
# Alarm Accuracy: 0.1294
# Accuracy: 0.7850
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11027  1539]
#  [  610   278]]
# Specificity: 0.8775
# Sensitivity: 0.3131
# Alarm Accuracy: 0.1530
# Accuracy: 0.8403
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 30---------------------------------------
# Epoch 30, Train Loss: 0.0750
# 整体验证集上的Loss: 0.13155405505325177
# AUROC: 0.5359
# Best threshold: 0.4217
# AUPRC: 0.1079
# Best threshold: 0.4324
# auc
# Confusion Matrix:
# [[10516  2050]
#  [  574   314]]
# Specificity: 0.8369
# Sensitivity: 0.3536
# Alarm Accuracy: 0.1328
# Accuracy: 0.8050
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10546  2020]
#  [  577   311]]
# Specificity: 0.8392
# Sensitivity: 0.3502
# Alarm Accuracy: 0.1334
# Accuracy: 0.8070
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 31---------------------------------------
# Epoch 31, Train Loss: 0.0755
# 整体验证集上的Loss: 0.10466311740039896
# AUROC: 0.5310
# Best threshold: 0.0029
# AUPRC: 0.1046
# Best threshold: 0.0029
# auc
# Confusion Matrix:
# [[10368  2198]
#  [  555   333]]
# Specificity: 0.8251
# Sensitivity: 0.3750
# Alarm Accuracy: 0.1316
# Accuracy: 0.7954
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10368  2198]
#  [  555   333]]
# Specificity: 0.8251
# Sensitivity: 0.3750
# Alarm Accuracy: 0.1316
# Accuracy: 0.7954
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 32---------------------------------------
# Epoch 32, Train Loss: 0.0757
# 整体验证集上的Loss: 0.08919142965302644
# AUROC: 0.4987
# Best threshold: 0.0004
# AUPRC: 0.0973
# Best threshold: 0.0130
# auc
# Confusion Matrix:
# [[10063  2503]
#  [  574   314]]
# Specificity: 0.8008
# Sensitivity: 0.3536
# Alarm Accuracy: 0.1115
# Accuracy: 0.7713
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11797   769]
#  [  718   170]]
# Specificity: 0.9388
# Sensitivity: 0.1914
# Alarm Accuracy: 0.1810
# Accuracy: 0.8895
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 33---------------------------------------
# Epoch 33, Train Loss: 0.0787
# 整体验证集上的Loss: 0.09698399383098108
# AUROC: 0.5475
# Best threshold: 0.0261
# AUPRC: 0.1131
# Best threshold: 0.0350
# auc
# Confusion Matrix:
# [[10332  2234]
#  [  556   332]]
# Specificity: 0.8222
# Sensitivity: 0.3739
# Alarm Accuracy: 0.1294
# Accuracy: 0.7926
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10580  1986]
#  [  575   313]]
# Specificity: 0.8420
# Sensitivity: 0.3525
# Alarm Accuracy: 0.1361
# Accuracy: 0.8096
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 34---------------------------------------
# Epoch 34, Train Loss: 0.0746
# 整体验证集上的Loss: 0.13681461750846438
# AUROC: 0.6043
# Best threshold: 0.4626
# AUPRC: 0.1203
# Best threshold: 0.5099
# auc
# Confusion Matrix:
# [[10414  2152]
#  [  531   357]]
# Specificity: 0.8287
# Sensitivity: 0.4020
# Alarm Accuracy: 0.1423
# Accuracy: 0.8006
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10641  1925]
#  [  554   334]]
# Specificity: 0.8468
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1479
# Accuracy: 0.8157
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 35---------------------------------------
# Epoch 35, Train Loss: 0.0813
# 整体验证集上的Loss: 0.100534276889907
# AUROC: 0.5756
# Best threshold: 0.1893
# AUPRC: 0.1188
# Best threshold: 0.2102
# auc
# Confusion Matrix:
# [[10453  2113]
#  [  554   334]]
# Specificity: 0.8318
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1365
# Accuracy: 0.8018
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10974  1592]
#  [  625   263]]
# Specificity: 0.8733
# Sensitivity: 0.2962
# Alarm Accuracy: 0.1418
# Accuracy: 0.8352
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 36---------------------------------------
# Epoch 36, Train Loss: 0.0753
# 整体验证集上的Loss: 0.09116502057008391
# AUROC: 0.5369
# Best threshold: 0.0016
# AUPRC: 0.1096
# Best threshold: 0.0053
# auc
# Confusion Matrix:
# [[10118  2448]
#  [  554   334]]
# Specificity: 0.8052
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1201
# Accuracy: 0.7769
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10879  1687]
#  [  619   269]]
# Specificity: 0.8657
# Sensitivity: 0.3029
# Alarm Accuracy: 0.1375
# Accuracy: 0.8286
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 37---------------------------------------
# Epoch 37, Train Loss: 0.0742
# 整体验证集上的Loss: 0.10243906279894158
# AUROC: 0.5240
# Best threshold: 0.0321
# AUPRC: 0.1082
# Best threshold: 0.4351
# auc
# Confusion Matrix:
# [[10100  2466]
#  [  559   329]]
# Specificity: 0.8038
# Sensitivity: 0.3705
# Alarm Accuracy: 0.1177
# Accuracy: 0.7752
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11927   639]
#  [  725   163]]
# Specificity: 0.9491
# Sensitivity: 0.1836
# Alarm Accuracy: 0.2032
# Accuracy: 0.8986
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 38---------------------------------------
# Epoch 38, Train Loss: 0.0764
# 整体验证集上的Loss: 0.08781784502933644
# AUROC: 0.5370
# Best threshold: 0.0000
# AUPRC: 0.1048
# Best threshold: 0.0004
# auc
# Confusion Matrix:
# [[10204  2362]
#  [  551   337]]
# Specificity: 0.8120
# Sensitivity: 0.3795
# Alarm Accuracy: 0.1249
# Accuracy: 0.7835
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11900   666]
#  [  726   162]]
# Specificity: 0.9470
# Sensitivity: 0.1824
# Alarm Accuracy: 0.1957
# Accuracy: 0.8965
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 39---------------------------------------
# Epoch 39, Train Loss: 0.0789
# 整体验证集上的Loss: 0.12169689663519684
# AUROC: 0.5477
# Best threshold: 0.2172
# AUPRC: 0.1227
# Best threshold: 0.4011
# auc
# Confusion Matrix:
# [[10098  2468]
#  [  548   340]]
# Specificity: 0.8036
# Sensitivity: 0.3829
# Alarm Accuracy: 0.1211
# Accuracy: 0.7758
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11042  1524]
#  [  632   256]]
# Specificity: 0.8787
# Sensitivity: 0.2883
# Alarm Accuracy: 0.1438
# Accuracy: 0.8398
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 40---------------------------------------
# Epoch 40, Train Loss: 0.0765
# 整体验证集上的Loss: 0.09610313514253829
# AUROC: 0.5222
# Best threshold: 0.0074
# AUPRC: 0.1037
# Best threshold: 0.2623
# auc
# Confusion Matrix:
# [[10067  2499]
#  [  544   344]]
# Specificity: 0.8011
# Sensitivity: 0.3874
# Alarm Accuracy: 0.1210
# Accuracy: 0.7738
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11925   641]
#  [  724   164]]
# Specificity: 0.9490
# Sensitivity: 0.1847
# Alarm Accuracy: 0.2037
# Accuracy: 0.8985
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 41---------------------------------------
# Epoch 41, Train Loss: 0.0770
# 整体验证集上的Loss: 0.12998895546289727
# AUROC: 0.5315
# Best threshold: 0.3074
# AUPRC: 0.1162
# Best threshold: 0.4848
# auc
# Confusion Matrix:
# [[10215  2351]
#  [  554   334]]
# Specificity: 0.8129
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1244
# Accuracy: 0.7841
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10830  1736]
#  [  613   275]]
# Specificity: 0.8618
# Sensitivity: 0.3097
# Alarm Accuracy: 0.1367
# Accuracy: 0.8254
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 42---------------------------------------
# Epoch 42, Train Loss: 0.0756
# 整体验证集上的Loss: 0.1160732861519213
# AUROC: 0.5947
# Best threshold: 0.2398
# AUPRC: 0.1208
# Best threshold: 0.3023
# auc
# Confusion Matrix:
# [[10367  2199]
#  [  529   359]]
# Specificity: 0.8250
# Sensitivity: 0.4043
# Alarm Accuracy: 0.1403
# Accuracy: 0.7972
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10768  1798]
#  [  571   317]]
# Specificity: 0.8569
# Sensitivity: 0.3570
# Alarm Accuracy: 0.1499
# Accuracy: 0.8239
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 43---------------------------------------
# Epoch 43, Train Loss: 0.0798
# 整体验证集上的Loss: 0.09753740722871711
# AUROC: 0.5205
# Best threshold: 0.0190
# AUPRC: 0.1061
# Best threshold: 0.2475
# auc
# Confusion Matrix:
# [[9830 2736]
#  [ 543  345]]
# Specificity: 0.7823
# Sensitivity: 0.3885
# Alarm Accuracy: 0.1120
# Accuracy: 0.7563
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11911   655]
#  [  723   165]]
# Specificity: 0.9479
# Sensitivity: 0.1858
# Alarm Accuracy: 0.2012
# Accuracy: 0.8976
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 44---------------------------------------
# Epoch 44, Train Loss: 0.0782
# 整体验证集上的Loss: 0.10577189955935655
# AUROC: 0.5742
# Best threshold: 0.0511
# AUPRC: 0.1106
# Best threshold: 0.0527
# auc
# Confusion Matrix:
# [[10483  2083]
#  [  555   333]]
# Specificity: 0.8342
# Sensitivity: 0.3750
# Alarm Accuracy: 0.1378
# Accuracy: 0.8039
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10503  2063]
#  [  557   331]]
# Specificity: 0.8358
# Sensitivity: 0.3727
# Alarm Accuracy: 0.1383
# Accuracy: 0.8053
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 45---------------------------------------
# Epoch 45, Train Loss: 0.0785
# 整体验证集上的Loss: 0.08709259006097582
# AUROC: 0.5057
# Best threshold: 0.0000
# AUPRC: 0.0975
# Best threshold: 0.0001
# auc
# Confusion Matrix:
# [[10636  1930]
#  [  619   269]]
# Specificity: 0.8464
# Sensitivity: 0.3029
# Alarm Accuracy: 0.1223
# Accuracy: 0.8105
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11892   674]
#  [  723   165]]
# Specificity: 0.9464
# Sensitivity: 0.1858
# Alarm Accuracy: 0.1967
# Accuracy: 0.8962
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 46---------------------------------------
# Epoch 46, Train Loss: 0.0779
# 整体验证集上的Loss: 0.10419709765738029
# AUROC: 0.5387
# Best threshold: 0.0363
# AUPRC: 0.1079
# Best threshold: 0.0421
# auc
# Confusion Matrix:
# [[10271  2295]
#  [  558   330]]
# Specificity: 0.8174
# Sensitivity: 0.3716
# Alarm Accuracy: 0.1257
# Accuracy: 0.7879
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10395  2171]
#  [  567   321]]
# Specificity: 0.8272
# Sensitivity: 0.3615
# Alarm Accuracy: 0.1288
# Accuracy: 0.7965
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 47---------------------------------------
# Epoch 47, Train Loss: 0.0793
# 整体验证集上的Loss: 0.09155055031117687
# AUROC: 0.5239
# Best threshold: 0.0232
# AUPRC: 0.1089
# Best threshold: 0.1181
# auc
# Confusion Matrix:
# [[10441  2125]
#  [  590   298]]
# Specificity: 0.8309
# Sensitivity: 0.3356
# Alarm Accuracy: 0.1230
# Accuracy: 0.7982
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11844   722]
#  [  722   166]]
# Specificity: 0.9425
# Sensitivity: 0.1869
# Alarm Accuracy: 0.1869
# Accuracy: 0.8927
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 48---------------------------------------
# Epoch 48, Train Loss: 0.0729
# 整体验证集上的Loss: 0.09509791274250878
# AUROC: 0.5322
# Best threshold: 0.0022
# AUPRC: 0.1025
# Best threshold: 0.2560
# auc
# Confusion Matrix:
# [[10025  2541]
#  [  554   334]]
# Specificity: 0.7978
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1162
# Accuracy: 0.7700
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11881   685]
#  [  724   164]]
# Specificity: 0.9455
# Sensitivity: 0.1847
# Alarm Accuracy: 0.1932
# Accuracy: 0.8953
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 49---------------------------------------
# Epoch 49, Train Loss: 0.0785
# 整体验证集上的Loss: 0.08697445862208474
# AUROC: 0.5627
# Best threshold: 0.0002
# AUPRC: 0.1197
# Best threshold: 0.0007
# auc
# Confusion Matrix:
# [[10465  2101]
#  [  574   314]]
# Specificity: 0.8328
# Sensitivity: 0.3536
# Alarm Accuracy: 0.1300
# Accuracy: 0.8012
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11166  1400]
#  [  647   241]]
# Specificity: 0.8886
# Sensitivity: 0.2714
# Alarm Accuracy: 0.1469
# Accuracy: 0.8479
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 50---------------------------------------
# Epoch 50, Train Loss: 0.0750
# 整体验证集上的Loss: 0.0963258746646422
# AUROC: 0.5335
# Best threshold: 0.0204
# AUPRC: 0.1116
# Best threshold: 0.2884
# auc
# Confusion Matrix:
# [[10220  2346]
#  [  560   328]]
# Specificity: 0.8133
# Sensitivity: 0.3694
# Alarm Accuracy: 0.1227
# Accuracy: 0.7840
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11895   671]
#  [  721   167]]
# Specificity: 0.9466
# Sensitivity: 0.1881
# Alarm Accuracy: 0.1993
# Accuracy: 0.8965
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 51---------------------------------------
# Epoch 51, Train Loss: 0.0710
# 整体验证集上的Loss: 0.09304336216100058
# AUROC: 0.5429
# Best threshold: 0.0027
# AUPRC: 0.1167
# Best threshold: 0.0110
# auc
# Confusion Matrix:
# [[10158  2408]
#  [  554   334]]
# Specificity: 0.8084
# Sensitivity: 0.3761
# Alarm Accuracy: 0.1218
# Accuracy: 0.7798
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11039  1527]
#  [  631   257]]
# Specificity: 0.8785
# Sensitivity: 0.2894
# Alarm Accuracy: 0.1441
# Accuracy: 0.8396
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 52---------------------------------------
# Epoch 52, Train Loss: 0.0751
# 整体验证集上的Loss: 0.1042716873513681
# AUROC: 0.5145
# Best threshold: 0.0141
# AUPRC: 0.1036
# Best threshold: 0.5956
# auc
# Confusion Matrix:
# [[10120  2446]
#  [  551   337]]
# Specificity: 0.8053
# Sensitivity: 0.3795
# Alarm Accuracy: 0.1211
# Accuracy: 0.7772
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11883   683]
#  [  725   163]]
# Specificity: 0.9456
# Sensitivity: 0.1836
# Alarm Accuracy: 0.1927
# Accuracy: 0.8953
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 53---------------------------------------
# Epoch 53, Train Loss: 0.0767
# 整体验证集上的Loss: 0.092305970472795
# AUROC: 0.5346
# Best threshold: 0.0249
# AUPRC: 0.1070
# Best threshold: 0.0592
# auc
# Confusion Matrix:
# [[10335  2231]
#  [  564   324]]
# Specificity: 0.8225
# Sensitivity: 0.3649
# Alarm Accuracy: 0.1268
# Accuracy: 0.7923
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11036  1530]
#  [  630   258]]
# Specificity: 0.8782
# Sensitivity: 0.2905
# Alarm Accuracy: 0.1443
# Accuracy: 0.8395
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 54---------------------------------------
# Epoch 54, Train Loss: 0.0768
# 整体验证集上的Loss: 0.10518572651063073
# AUROC: 0.5117
# Best threshold: 0.2528
# AUPRC: 0.0986
# Best threshold: 0.3130
# auc
# Confusion Matrix:
# [[10954  1612]
#  [  647   241]]
# Specificity: 0.8717
# Sensitivity: 0.2714
# Alarm Accuracy: 0.1301
# Accuracy: 0.8321
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11298  1268]
#  [  672   216]]
# Specificity: 0.8991
# Sensitivity: 0.2432
# Alarm Accuracy: 0.1456
# Accuracy: 0.8558
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 55---------------------------------------
# Epoch 55, Train Loss: 0.0792
# 整体验证集上的Loss: 0.08984204001386077
# AUROC: 0.5153
# Best threshold: 0.0009
# AUPRC: 0.1208
# Best threshold: 0.0940
# auc
# Confusion Matrix:
# [[10492  2074]
#  [  600   288]]
# Specificity: 0.8350
# Sensitivity: 0.3243
# Alarm Accuracy: 0.1219
# Accuracy: 0.8012
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11939   627]
#  [  722   166]]
# Specificity: 0.9501
# Sensitivity: 0.1869
# Alarm Accuracy: 0.2093
# Accuracy: 0.8997
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 56---------------------------------------
# Epoch 56, Train Loss: 0.0810
# 整体验证集上的Loss: 0.20035373232368187
# AUROC: 0.5292
# Best threshold: 0.7551
# AUPRC: 0.1121
# Best threshold: 0.8240
# auc
# Confusion Matrix:
# [[10236  2330]
#  [  577   311]]
# Specificity: 0.8146
# Sensitivity: 0.3502
# Alarm Accuracy: 0.1178
# Accuracy: 0.7839
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11219  1347]
#  [  655   233]]
# Specificity: 0.8928
# Sensitivity: 0.2624
# Alarm Accuracy: 0.1475
# Accuracy: 0.8512
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 57---------------------------------------
# Epoch 57, Train Loss: 0.0753
# Model has been saved into: model_saved_dir
# 整体验证集上的Loss: 0.10759148614763331
# AUROC: 0.5263
# Best threshold: 0.3322
# AUPRC: 0.1192
# Best threshold: 0.3331
# auc
# Confusion Matrix:
# [[10798  1768]
#  [  594   294]]
# Specificity: 0.8593
# Sensitivity: 0.3311
# Alarm Accuracy: 0.1426
# Accuracy: 0.8244
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11221  1345]
#  [  637   251]]
# Specificity: 0.8930
# Sensitivity: 0.2827
# Alarm Accuracy: 0.1573
# Accuracy: 0.8527
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 58---------------------------------------
# Epoch 58, Train Loss: 0.0748
# 整体验证集上的Loss: 0.09583080648761326
# AUROC: 0.5567
# Best threshold: 0.0008
# AUPRC: 0.1223
# Best threshold: 0.1549
# auc
# Confusion Matrix:
# [[10409  2157]
#  [  578   310]]
# Specificity: 0.8283
# Sensitivity: 0.3491
# Alarm Accuracy: 0.1257
# Accuracy: 0.7967
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12026   540]
#  [  726   162]]
# Specificity: 0.9570
# Sensitivity: 0.1824
# Alarm Accuracy: 0.2308
# Accuracy: 0.9059
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 59---------------------------------------
# Epoch 59, Train Loss: 0.0774
# 整体验证集上的Loss: 0.16757617952032444
# AUROC: 0.6108
# Best threshold: 0.6289
# AUPRC: 0.1212
# Best threshold: 0.7083
# auc
# Confusion Matrix:
# [[9674 2892]
#  [ 507  381]]
# Specificity: 0.7699
# Sensitivity: 0.4291
# Alarm Accuracy: 0.1164
# Accuracy: 0.7474
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11233  1333]
#  [  641   247]]
# Specificity: 0.8939
# Sensitivity: 0.2782
# Alarm Accuracy: 0.1563
# Accuracy: 0.8533
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 60---------------------------------------
# Epoch 60, Train Loss: 0.0769
# 整体验证集上的Loss: 0.17609016492900142
# AUROC: 0.5908
# Best threshold: 0.7457
# AUPRC: 0.1232
# Best threshold: 0.7947
# auc
# Confusion Matrix:
# [[10048  2518]
#  [  526   362]]
# Specificity: 0.7996
# Sensitivity: 0.4077
# Alarm Accuracy: 0.1257
# Accuracy: 0.7737
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10970  1596]
#  [  608   280]]
# Specificity: 0.8730
# Sensitivity: 0.3153
# Alarm Accuracy: 0.1493
# Accuracy: 0.8362
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 61---------------------------------------
# Epoch 61, Train Loss: 0.0791
# 整体验证集上的Loss: 0.08664319063163688
# AUROC: 0.6050
# Best threshold: 0.0000
# AUPRC: 0.1106
# Best threshold: 0.0000
# auc
# Confusion Matrix:
# [[10469  2097]
#  [  578   310]]
# Specificity: 0.8331
# Sensitivity: 0.3491
# Alarm Accuracy: 0.1288
# Accuracy: 0.8012
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10505  2061]
#  [  581   307]]
# Specificity: 0.8360
# Sensitivity: 0.3457
# Alarm Accuracy: 0.1296
# Accuracy: 0.8036
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 62---------------------------------------
# Epoch 62, Train Loss: 0.0778
# 整体验证集上的Loss: 0.0888521467694883
# AUROC: 0.5763
# Best threshold: 0.0030
# AUPRC: 0.1184
# Best threshold: 0.0700
# auc
# Confusion Matrix:
# [[10549  2017]
#  [  572   316]]
# Specificity: 0.8395
# Sensitivity: 0.3559
# Alarm Accuracy: 0.1354
# Accuracy: 0.8076
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11998   568]
#  [  727   161]]
# Specificity: 0.9548
# Sensitivity: 0.1813
# Alarm Accuracy: 0.2209
# Accuracy: 0.9037
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 63---------------------------------------
# Epoch 63, Train Loss: 0.0731
# 整体验证集上的Loss: 0.276565305120892
# AUROC: 0.5522
# Best threshold: 0.8343
# AUPRC: 0.0996
# Best threshold: 0.8370
# auc
# Confusion Matrix:
# [[10525  2041]
#  [  598   290]]
# Specificity: 0.8376
# Sensitivity: 0.3266
# Alarm Accuracy: 0.1244
# Accuracy: 0.8039
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10586  1980]
#  [  603   285]]
# Specificity: 0.8424
# Sensitivity: 0.3209
# Alarm Accuracy: 0.1258
# Accuracy: 0.8080
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 64---------------------------------------
# Epoch 64, Train Loss: 0.0780
# 整体验证集上的Loss: 0.14705010150806994
# AUROC: 0.5650
# Best threshold: 0.4055
# AUPRC: 0.1079
# Best threshold: 0.4058
# auc
# Confusion Matrix:
# [[11619   947]
#  [  702   186]]
# Specificity: 0.9246
# Sensitivity: 0.2095
# Alarm Accuracy: 0.1642
# Accuracy: 0.8774
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11770   796]
#  [  717   171]]
# Specificity: 0.9367
# Sensitivity: 0.1926
# Alarm Accuracy: 0.1768
# Accuracy: 0.8875
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 65---------------------------------------
# Epoch 65, Train Loss: 0.0783
# 整体验证集上的Loss: 0.13578614488181362
# AUROC: 0.5672
# Best threshold: 0.1535
# AUPRC: 0.1199
# Best threshold: 0.4361
# auc
# Confusion Matrix:
# [[10191  2375]
#  [  545   343]]
# Specificity: 0.8110
# Sensitivity: 0.3863
# Alarm Accuracy: 0.1262
# Accuracy: 0.7830
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10792  1774]
#  [  589   299]]
# Specificity: 0.8588
# Sensitivity: 0.3367
# Alarm Accuracy: 0.1442
# Accuracy: 0.8244
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 66---------------------------------------
# Epoch 66, Train Loss: 0.0766
# 整体验证集上的Loss: 0.12507626365117674
# AUROC: 0.5774
# Best threshold: 0.3489
# AUPRC: 0.1048
# Best threshold: 0.3508
# auc
# Confusion Matrix:
# [[9868 2698]
#  [ 526  362]]
# Specificity: 0.7853
# Sensitivity: 0.4077
# Alarm Accuracy: 0.1183
# Accuracy: 0.7604
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10350  2216]
#  [  566   322]]
# Specificity: 0.8237
# Sensitivity: 0.3626
# Alarm Accuracy: 0.1269
# Accuracy: 0.7932
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 67---------------------------------------
# Epoch 67, Train Loss: 0.0790
# 整体验证集上的Loss: 0.1466918742816007
# AUROC: 0.5740
# Best threshold: 0.4495
# AUPRC: 0.1135
# Best threshold: 0.4918
# auc
# Confusion Matrix:
# [[10159  2407]
#  [  561   327]]
# Specificity: 0.8085
# Sensitivity: 0.3682
# Alarm Accuracy: 0.1196
# Accuracy: 0.7794
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12028   538]
#  [  734   154]]
# Specificity: 0.9572
# Sensitivity: 0.1734
# Alarm Accuracy: 0.2225
# Accuracy: 0.9055
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 68---------------------------------------
# Epoch 68, Train Loss: 0.0769
# 整体验证集上的Loss: 0.14238104726918538
# AUROC: 0.5312
# Best threshold: 0.2117
# AUPRC: 0.0784
# Best threshold: 0.4250
# auc
# Confusion Matrix:
# [[6519 6047]
#  [ 377  511]]
# Specificity: 0.5188
# Sensitivity: 0.5755
# Alarm Accuracy: 0.0779
# Accuracy: 0.5225
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[7931 4635]
#  [ 479  409]]
# Specificity: 0.6311
# Sensitivity: 0.4606
# Alarm Accuracy: 0.0811
# Accuracy: 0.6199
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 69---------------------------------------
# Epoch 69, Train Loss: 0.0727
# 整体验证集上的Loss: 0.10178654343378986
# AUROC: 0.5887
# Best threshold: 0.1415
# AUPRC: 0.1015
# Best threshold: 0.1924
# auc
# Confusion Matrix:
# [[10607  1959]
#  [  605   283]]
# Specificity: 0.8441
# Sensitivity: 0.3187
# Alarm Accuracy: 0.1262
# Accuracy: 0.8094
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10811  1755]
#  [  623   265]]
# Specificity: 0.8603
# Sensitivity: 0.2984
# Alarm Accuracy: 0.1312
# Accuracy: 0.8232
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 70---------------------------------------
# Epoch 70, Train Loss: 0.0738
# 整体验证集上的Loss: 0.11893315619277954
# AUROC: 0.5763
# Best threshold: 0.0073
# AUPRC: 0.1103
# Best threshold: 0.0977
# auc
# Confusion Matrix:
# [[9891 2675]
#  [ 531  357]]
# Specificity: 0.7871
# Sensitivity: 0.4020
# Alarm Accuracy: 0.1177
# Accuracy: 0.7617
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10905  1661]
#  [  608   280]]
# Specificity: 0.8678
# Sensitivity: 0.3153
# Alarm Accuracy: 0.1443
# Accuracy: 0.8314
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 71---------------------------------------
# Epoch 71, Train Loss: 0.0750
# 整体验证集上的Loss: 0.1401053336532381
# AUROC: 0.5510
# Best threshold: 0.4175
# AUPRC: 0.0939
# Best threshold: 0.4631
# auc
# Confusion Matrix:
# [[10034  2532]
#  [  540   348]]
# Specificity: 0.7985
# Sensitivity: 0.3919
# Alarm Accuracy: 0.1208
# Accuracy: 0.7717
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11190  1376]
#  [  638   250]]
# Specificity: 0.8905
# Sensitivity: 0.2815
# Alarm Accuracy: 0.1538
# Accuracy: 0.8503
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 72---------------------------------------
# Epoch 72, Train Loss: 0.0774
# 整体验证集上的Loss: 0.10693951067486517
# AUROC: 0.5989
# Best threshold: 0.0444
# AUPRC: 0.1102
# Best threshold: 0.0613
# auc
# Confusion Matrix:
# [[10597  1969]
#  [  563   325]]
# Specificity: 0.8433
# Sensitivity: 0.3660
# Alarm Accuracy: 0.1417
# Accuracy: 0.8118
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10806  1760]
#  [  581   307]]
# Specificity: 0.8599
# Sensitivity: 0.3457
# Alarm Accuracy: 0.1485
# Accuracy: 0.8260
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 73---------------------------------------
# Epoch 73, Train Loss: 0.0737
# 整体验证集上的Loss: 0.11684347336428254
# AUROC: 0.5720
# Best threshold: 0.4826
# AUPRC: 0.1111
# Best threshold: 0.5369
# auc
# Confusion Matrix:
# [[10631  1935]
#  [  594   294]]
# Specificity: 0.8460
# Sensitivity: 0.3311
# Alarm Accuracy: 0.1319
# Accuracy: 0.8120
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12070   496]
#  [  739   149]]
# Specificity: 0.9605
# Sensitivity: 0.1678
# Alarm Accuracy: 0.2310
# Accuracy: 0.9082
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 74---------------------------------------
# Epoch 74, Train Loss: 0.0736
# 整体验证集上的Loss: 0.14855674467090324
# AUROC: 0.5665
# Best threshold: 0.4669
# AUPRC: 0.1041
# Best threshold: 0.4738
# auc
# Confusion Matrix:
# [[10892  1674]
#  [  621   267]]
# Specificity: 0.8668
# Sensitivity: 0.3007
# Alarm Accuracy: 0.1376
# Accuracy: 0.8294
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10995  1571]
#  [  629   259]]
# Specificity: 0.8750
# Sensitivity: 0.2917
# Alarm Accuracy: 0.1415
# Accuracy: 0.8365
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 75---------------------------------------
# Epoch 75, Train Loss: 0.0778
# 整体验证集上的Loss: 0.22043629658932157
# AUROC: 0.6147
# Best threshold: 0.8423
# AUPRC: 0.1201
# Best threshold: 0.9907
# auc
# Confusion Matrix:
# [[8999 3567]
#  [ 417  471]]
# Specificity: 0.7161
# Sensitivity: 0.5304
# Alarm Accuracy: 0.1166
# Accuracy: 0.7039
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11498  1068]
#  [  663   225]]
# Specificity: 0.9150
# Sensitivity: 0.2534
# Alarm Accuracy: 0.1740
# Accuracy: 0.8713
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 76---------------------------------------
# Epoch 76, Train Loss: 0.0748
# 整体验证集上的Loss: 0.11655426610888375
# AUROC: 0.6128
# Best threshold: 0.0048
# AUPRC: 0.1117
# Best threshold: 0.0322
# auc
# Confusion Matrix:
# [[10131  2435]
#  [  541   347]]
# Specificity: 0.8062
# Sensitivity: 0.3908
# Alarm Accuracy: 0.1247
# Accuracy: 0.7788
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10726  1840]
#  [  594   294]]
# Specificity: 0.8536
# Sensitivity: 0.3311
# Alarm Accuracy: 0.1378
# Accuracy: 0.8191
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 77---------------------------------------
# Epoch 77, Train Loss: 0.0699
# 整体验证集上的Loss: 0.08931771285493285
# AUROC: 0.6605
# Best threshold: 0.0001
# AUPRC: 0.1202
# Best threshold: 0.0035
# auc
# Confusion Matrix:
# [[4560 8006]
#  [  57  831]]
# Specificity: 0.3629
# Sensitivity: 0.9358
# Alarm Accuracy: 0.0940
# Accuracy: 0.4007
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10544  2022]
#  [  604   284]]
# Specificity: 0.8391
# Sensitivity: 0.3198
# Alarm Accuracy: 0.1232
# Accuracy: 0.8048
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 78---------------------------------------
# Epoch 78, Train Loss: 0.0740
# 整体验证集上的Loss: 0.09509326799537518
# AUROC: 0.5988
# Best threshold: 0.0001
# AUPRC: 0.1055
# Best threshold: 0.2185
# auc
# Confusion Matrix:
# [[3306 9260]
#  [  84  804]]
# Specificity: 0.2631
# Sensitivity: 0.9054
# Alarm Accuracy: 0.0799
# Accuracy: 0.3055
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11864   702]
#  [  722   166]]
# Specificity: 0.9441
# Sensitivity: 0.1869
# Alarm Accuracy: 0.1912
# Accuracy: 0.8942
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 79---------------------------------------
# Epoch 79, Train Loss: 0.0743
# 整体验证集上的Loss: 0.13233846818344683
# AUROC: 0.5695
# Best threshold: 0.3552
# AUPRC: 0.0913
# Best threshold: 0.4626
# auc
# Confusion Matrix:
# [[9432 3134]
#  [ 551  337]]
# Specificity: 0.7506
# Sensitivity: 0.3795
# Alarm Accuracy: 0.0971
# Accuracy: 0.7261
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11234  1332]
#  [  681   207]]
# Specificity: 0.8940
# Sensitivity: 0.2331
# Alarm Accuracy: 0.1345
# Accuracy: 0.8504
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 80---------------------------------------
# Epoch 80, Train Loss: 0.0770
# 整体验证集上的Loss: 0.08756042940134473
# AUROC: 0.7146
# Best threshold: 0.0000
# AUPRC: 0.1396
# Best threshold: 0.0000
# auc
# Confusion Matrix:
# [[4652 7914]
#  [  30  858]]
# Specificity: 0.3702
# Sensitivity: 0.9662
# Alarm Accuracy: 0.0978
# Accuracy: 0.4095
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[9207 3359]
#  [ 424  464]]
# Specificity: 0.7327
# Sensitivity: 0.5225
# Alarm Accuracy: 0.1214
# Accuracy: 0.7188
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 81---------------------------------------
# Epoch 81, Train Loss: 0.0754
# 整体验证集上的Loss: 0.12542991622115948
# AUROC: 0.6599
# Best threshold: 0.0142
# AUPRC: 0.0892
# Best threshold: 0.0143
# auc
# Confusion Matrix:
# [[6018 6548]
#  [ 141  747]]
# Specificity: 0.4789
# Sensitivity: 0.8412
# Alarm Accuracy: 0.1024
# Accuracy: 0.5028
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[6032 6534]
#  [ 142  746]]
# Specificity: 0.4800
# Sensitivity: 0.8401
# Alarm Accuracy: 0.1025
# Accuracy: 0.5038
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 82---------------------------------------
# Epoch 82, Train Loss: 0.0748
# 整体验证集上的Loss: 0.09192747021652152
# AUROC: 0.5753
# Best threshold: 0.0010
# AUPRC: 0.1200
# Best threshold: 0.1071
# auc
# Confusion Matrix:
# [[10331  2235]
#  [  572   316]]
# Specificity: 0.8221
# Sensitivity: 0.3559
# Alarm Accuracy: 0.1239
# Accuracy: 0.7914
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12021   545]
#  [  730   158]]
# Specificity: 0.9566
# Sensitivity: 0.1779
# Alarm Accuracy: 0.2248
# Accuracy: 0.9052
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 83---------------------------------------
# Epoch 83, Train Loss: 0.0771
# 整体验证集上的Loss: 0.11873432282433687
# AUROC: 0.5416
# Best threshold: 0.2785
# AUPRC: 0.0788
# Best threshold: 0.2785
# auc
# Confusion Matrix:
# [[8948 3618]
#  [ 525  363]]
# Specificity: 0.7121
# Sensitivity: 0.4088
# Alarm Accuracy: 0.0912
# Accuracy: 0.6921
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[8948 3618]
#  [ 525  363]]
# Specificity: 0.7121
# Sensitivity: 0.4088
# Alarm Accuracy: 0.0912
# Accuracy: 0.6921
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 84---------------------------------------
# Epoch 84, Train Loss: 0.0752
# 整体验证集上的Loss: 0.09670205392708603
# AUROC: 0.5725
# Best threshold: 0.0009
# AUPRC: 0.1062
# Best threshold: 0.0174
# auc
# Confusion Matrix:
# [[9233 3333]
#  [ 482  406]]
# Specificity: 0.7348
# Sensitivity: 0.4572
# Alarm Accuracy: 0.1086
# Accuracy: 0.7164
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11083  1483]
#  [  619   269]]
# Specificity: 0.8820
# Sensitivity: 0.3029
# Alarm Accuracy: 0.1535
# Accuracy: 0.8438
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 85---------------------------------------
# Epoch 85, Train Loss: 0.0728
# 整体验证集上的Loss: 0.13947074010905514
# AUROC: 0.5823
# Best threshold: 0.4917
# AUPRC: 0.1073
# Best threshold: 0.8412
# auc
# Confusion Matrix:
# [[10419  2147]
#  [  549   339]]
# Specificity: 0.8291
# Sensitivity: 0.3818
# Alarm Accuracy: 0.1364
# Accuracy: 0.7996
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11329  1237]
#  [  639   249]]
# Specificity: 0.9016
# Sensitivity: 0.2804
# Alarm Accuracy: 0.1676
# Accuracy: 0.8606
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 86---------------------------------------
# Epoch 86, Train Loss: 0.0750
# 整体验证集上的Loss: 0.12331876964969989
# AUROC: 0.5662
# Best threshold: 0.1624
# AUPRC: 0.1015
# Best threshold: 0.2624
# auc
# Confusion Matrix:
# [[10459  2107]
#  [  563   325]]
# Specificity: 0.8323
# Sensitivity: 0.3660
# Alarm Accuracy: 0.1336
# Accuracy: 0.8015
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10729  1837]
#  [  591   297]]
# Specificity: 0.8538
# Sensitivity: 0.3345
# Alarm Accuracy: 0.1392
# Accuracy: 0.8195
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 87---------------------------------------
# Epoch 87, Train Loss: 0.0733
# 整体验证集上的Loss: 0.13015022410775998
# AUROC: 0.5583
# Best threshold: 0.4775
# AUPRC: 0.1007
# Best threshold: 0.6323
# auc
# Confusion Matrix:
# [[10609  1957]
#  [  568   320]]
# Specificity: 0.8443
# Sensitivity: 0.3604
# Alarm Accuracy: 0.1405
# Accuracy: 0.8123
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11152  1414]
#  [  620   268]]
# Specificity: 0.8875
# Sensitivity: 0.3018
# Alarm Accuracy: 0.1593
# Accuracy: 0.8488
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 88---------------------------------------
# Epoch 88, Train Loss: 0.0743
# 整体验证集上的Loss: 0.12080832963125794
# AUROC: 0.5488
# Best threshold: 0.4275
# AUPRC: 0.0972
# Best threshold: 0.4938
# auc
# Confusion Matrix:
# [[11059  1507]
#  [  624   264]]
# Specificity: 0.8801
# Sensitivity: 0.2973
# Alarm Accuracy: 0.1491
# Accuracy: 0.8416
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11212  1354]
#  [  637   251]]
# Specificity: 0.8922
# Sensitivity: 0.2827
# Alarm Accuracy: 0.1564
# Accuracy: 0.8520
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 89---------------------------------------
# Epoch 89, Train Loss: 0.0736
# 整体验证集上的Loss: 0.10909562646728092
# AUROC: 0.5782
# Best threshold: 0.0133
# AUPRC: 0.1176
# Best threshold: 0.0145
# auc
# Confusion Matrix:
# [[10406  2160]
#  [  550   338]]
# Specificity: 0.8281
# Sensitivity: 0.3806
# Alarm Accuracy: 0.1353
# Accuracy: 0.7986
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10437  2129]
#  [  553   335]]
# Specificity: 0.8306
# Sensitivity: 0.3773
# Alarm Accuracy: 0.1360
# Accuracy: 0.8007
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 90---------------------------------------
# Epoch 90, Train Loss: 0.0745
# 整体验证集上的Loss: 0.10699034984954199
# AUROC: 0.6417
# Best threshold: 0.0013
# AUPRC: 0.0939
# Best threshold: 0.3380
# auc
# Confusion Matrix:
# [[4518 8048]
#  [ 122  766]]
# Specificity: 0.3595
# Sensitivity: 0.8626
# Alarm Accuracy: 0.0869
# Accuracy: 0.3927
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11449  1117]
#  [  705   183]]
# Specificity: 0.9111
# Sensitivity: 0.2061
# Alarm Accuracy: 0.1408
# Accuracy: 0.8646
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 91---------------------------------------
# Epoch 91, Train Loss: 0.0784
# 整体验证集上的Loss: 0.09612899555589535
# AUROC: 0.5627
# Best threshold: 0.0097
# AUPRC: 0.0828
# Best threshold: 0.0104
# auc
# Confusion Matrix:
# [[10444  2122]
#  [  582   306]]
# Specificity: 0.8311
# Sensitivity: 0.3446
# Alarm Accuracy: 0.1260
# Accuracy: 0.7990
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10471  2095]
#  [  584   304]]
# Specificity: 0.8333
# Sensitivity: 0.3423
# Alarm Accuracy: 0.1267
# Accuracy: 0.8009
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 92---------------------------------------
# Epoch 92, Train Loss: 0.0764
# 整体验证集上的Loss: 0.11644567886373733
# AUROC: 0.5854
# Best threshold: 0.0717
# AUPRC: 0.1040
# Best threshold: 0.4368
# auc
# Confusion Matrix:
# [[10001  2565]
#  [  535   353]]
# Specificity: 0.7959
# Sensitivity: 0.3975
# Alarm Accuracy: 0.1210
# Accuracy: 0.7696
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11186  1380]
#  [  630   258]]
# Specificity: 0.8902
# Sensitivity: 0.2905
# Alarm Accuracy: 0.1575
# Accuracy: 0.8506
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 93---------------------------------------
# Epoch 93, Train Loss: 0.0744
# 整体验证集上的Loss: 0.12113003135216678
# AUROC: 0.5962
# Best threshold: 0.1117
# AUPRC: 0.1065
# Best threshold: 0.6146
# auc
# Confusion Matrix:
# [[10246  2320]
#  [  556   332]]
# Specificity: 0.8154
# Sensitivity: 0.3739
# Alarm Accuracy: 0.1252
# Accuracy: 0.7862
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11342  1224]
#  [  659   229]]
# Specificity: 0.9026
# Sensitivity: 0.2579
# Alarm Accuracy: 0.1576
# Accuracy: 0.8600
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 94---------------------------------------
# Epoch 94, Train Loss: 0.0724
# 整体验证集上的Loss: 0.13879929820081924
# AUROC: 0.5357
# Best threshold: 0.6123
# AUPRC: 0.0930
# Best threshold: 0.6123
# auc
# Confusion Matrix:
# [[10936  1630]
#  [  604   284]]
# Specificity: 0.8703
# Sensitivity: 0.3198
# Alarm Accuracy: 0.1484
# Accuracy: 0.8340
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10936  1630]
#  [  604   284]]
# Specificity: 0.8703
# Sensitivity: 0.3198
# Alarm Accuracy: 0.1484
# Accuracy: 0.8340
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 95---------------------------------------
# ...
# Specificity: 0.7126
# Sensitivity: 0.7050
# Alarm Accuracy: 0.1477
# Accuracy: 0.7121
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12241   325]
#  [  623   265]]
# Specificity: 0.9741
# Sensitivity: 0.2984
# Alarm Accuracy: 0.4492
# Accuracy: 0.9295
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 70---------------------------------------
# Epoch 70, Train Loss: 0.0716
# 整体验证集上的Loss: 0.16722847968829122
# AUROC: 0.5390
# Best threshold: 0.8438
# AUPRC: 0.1529
# Best threshold: 0.9124
# auc
# Confusion Matrix:
# [[11643   923]
#  [  689   199]]
# Specificity: 0.9265
# Sensitivity: 0.2241
# Alarm Accuracy: 0.1774
# Accuracy: 0.8802
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12184   382]
#  [  745   143]]
# Specificity: 0.9696
# Sensitivity: 0.1610
# Alarm Accuracy: 0.2724
# Accuracy: 0.9162
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 71---------------------------------------
# Epoch 71, Train Loss: 0.0740
# 整体验证集上的Loss: 0.14907132150335667
# AUROC: 0.5342
# Best threshold: 0.7457
# AUPRC: 0.1401
# Best threshold: 0.8948
# auc
# Confusion Matrix:
# [[11084  1482]
#  [  664   224]]
# Specificity: 0.8821
# Sensitivity: 0.2523
# Alarm Accuracy: 0.1313
# Accuracy: 0.8405
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12070   496]
#  [  746   142]]
# Specificity: 0.9605
# Sensitivity: 0.1599
# Alarm Accuracy: 0.2226
# Accuracy: 0.9077
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 72---------------------------------------
# Epoch 72, Train Loss: 0.0716
# 整体验证集上的Loss: 0.0946760826689579
# AUROC: 0.5469
# Best threshold: 0.0012
# AUPRC: 0.1283
# Best threshold: 0.2036
# auc
# Confusion Matrix:
# [[8499 4067]
#  [ 448  440]]
# Specificity: 0.6763
# Sensitivity: 0.4955
# Alarm Accuracy: 0.0976
# Accuracy: 0.6644
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11654   912]
#  [  722   166]]
# Specificity: 0.9274
# Sensitivity: 0.1869
# Alarm Accuracy: 0.1540
# Accuracy: 0.8785
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 73---------------------------------------
# Epoch 73, Train Loss: 0.0702
# 整体验证集上的Loss: 0.10760882392462978
# AUROC: 0.7756
# Best threshold: 0.0015
# AUPRC: 0.2237
# Best threshold: 0.3283
# auc
# Confusion Matrix:
# [[7358 5208]
#  [ 120  768]]
# Specificity: 0.5855
# Sensitivity: 0.8649
# Alarm Accuracy: 0.1285
# Accuracy: 0.6040
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11552  1014]
#  [  560   328]]
# Specificity: 0.9193
# Sensitivity: 0.3694
# Alarm Accuracy: 0.2444
# Accuracy: 0.8830
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 74---------------------------------------
# Epoch 74, Train Loss: 0.0726
# 整体验证集上的Loss: 0.16401153919258823
# AUROC: 0.7214
# Best threshold: 0.9166
# AUPRC: 0.2763
# Best threshold: 0.9434
# auc
# Confusion Matrix:
# [[11554  1012]
#  [  490   398]]
# Specificity: 0.9195
# Sensitivity: 0.4482
# Alarm Accuracy: 0.2823
# Accuracy: 0.8884
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11810   756]
#  [  530   358]]
# Specificity: 0.9398
# Sensitivity: 0.4032
# Alarm Accuracy: 0.3214
# Accuracy: 0.9044
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 75---------------------------------------
# Epoch 75, Train Loss: 0.0724
# 整体验证集上的Loss: 0.1247077347552688
# AUROC: 0.6198
# Best threshold: 0.0013
# AUPRC: 0.1232
# Best threshold: 0.4979
# auc
# Confusion Matrix:
# [[4353 8213]
#  [ 111  777]]
# Specificity: 0.3464
# Sensitivity: 0.8750
# Alarm Accuracy: 0.0864
# Accuracy: 0.3813
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11459  1107]
#  [  628   260]]
# Specificity: 0.9119
# Sensitivity: 0.2928
# Alarm Accuracy: 0.1902
# Accuracy: 0.8710
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 76---------------------------------------
# Epoch 76, Train Loss: 0.0703
# 整体验证集上的Loss: 0.09082793229645271
# AUROC: 0.6305
# Best threshold: 0.0015
# AUPRC: 0.1229
# Best threshold: 0.0057
# auc
# Confusion Matrix:
# [[10324  2242]
#  [  654   234]]
# Specificity: 0.8216
# Sensitivity: 0.2635
# Alarm Accuracy: 0.0945
# Accuracy: 0.7847
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11423  1143]
#  [  708   180]]
# Specificity: 0.9090
# Sensitivity: 0.2027
# Alarm Accuracy: 0.1361
# Accuracy: 0.8624
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 77---------------------------------------
# Epoch 77, Train Loss: 0.0699
# 整体验证集上的Loss: 0.12711427256402263
# AUROC: 0.5066
# Best threshold: 0.5093
# AUPRC: 0.1444
# Best threshold: 0.7929
# auc
# Confusion Matrix:
# [[11570   996]
#  [  682   206]]
# Specificity: 0.9207
# Sensitivity: 0.2320
# Alarm Accuracy: 0.1714
# Accuracy: 0.8753
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12143   423]
#  [  735   153]]
# Specificity: 0.9663
# Sensitivity: 0.1723
# Alarm Accuracy: 0.2656
# Accuracy: 0.9139
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 78---------------------------------------
# Epoch 78, Train Loss: 0.0691
# 整体验证集上的Loss: 0.08862079630784636
# AUROC: 0.5009
# Best threshold: 0.0127
# AUPRC: 0.1139
# Best threshold: 0.0127
# auc
# Confusion Matrix:
# [[11892   674]
#  [  746   142]]
# Specificity: 0.9464
# Sensitivity: 0.1599
# Alarm Accuracy: 0.1740
# Accuracy: 0.8945
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11892   674]
#  [  746   142]]
# Specificity: 0.9464
# Sensitivity: 0.1599
# Alarm Accuracy: 0.1740
# Accuracy: 0.8945
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 79---------------------------------------
# Epoch 79, Train Loss: 0.0755
# 整体验证集上的Loss: 0.14133729929662633
# AUROC: 0.7719
# Best threshold: 0.2663
# AUPRC: 0.1855
# Best threshold: 0.6928
# auc
# Confusion Matrix:
# [[9742 2824]
#  [ 274  614]]
# Specificity: 0.7753
# Sensitivity: 0.6914
# Alarm Accuracy: 0.1786
# Accuracy: 0.7697
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11168  1398]
#  [  454   434]]
# Specificity: 0.8887
# Sensitivity: 0.4887
# Alarm Accuracy: 0.2369
# Accuracy: 0.8623
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 80---------------------------------------
# Epoch 80, Train Loss: 0.0729
# 整体验证集上的Loss: 0.09060003586878601
# AUROC: 0.3665
# Best threshold: 0.4712
# AUPRC: 0.0684
# Best threshold: 0.0012
# auc
# Confusion Matrix:
# [[12556    10]
#  [  871    17]]
# Specificity: 0.9992
# Sensitivity: 0.0191
# Alarm Accuracy: 0.6296
# Accuracy: 0.9345
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[   87 12479]
#  [    1   887]]
# Specificity: 0.0069
# Sensitivity: 0.9989
# Alarm Accuracy: 0.0664
# Accuracy: 0.0724
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 81---------------------------------------
# Epoch 81, Train Loss: 0.0716
# 整体验证集上的Loss: 0.16119727443151122
# AUROC: 0.6175
# Best threshold: 0.0015
# AUPRC: 0.1627
# Best threshold: 0.9635
# auc
# Confusion Matrix:
# [[5008 7558]
#  [ 208  680]]
# Specificity: 0.3985
# Sensitivity: 0.7658
# Alarm Accuracy: 0.0825
# Accuracy: 0.4228
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12234   332]
#  [  746   142]]
# Specificity: 0.9736
# Sensitivity: 0.1599
# Alarm Accuracy: 0.2996
# Accuracy: 0.9199
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 82---------------------------------------
# Epoch 82, Train Loss: 0.0669
# 整体验证集上的Loss: 0.2521824743509646
# AUROC: 0.4286
# Best threshold: 0.9278
# AUPRC: 0.1460
# Best threshold: 0.9739
# auc
# Confusion Matrix:
# [[10856  1710]
#  [  625   263]]
# Specificity: 0.8639
# Sensitivity: 0.2962
# Alarm Accuracy: 0.1333
# Accuracy: 0.8264
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12047   519]
#  [  733   155]]
# Specificity: 0.9587
# Sensitivity: 0.1745
# Alarm Accuracy: 0.2300
# Accuracy: 0.9069
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 83---------------------------------------
# Epoch 83, Train Loss: 0.0778
# 整体验证集上的Loss: 0.09255825596212458
# AUROC: 0.5316
# Best threshold: 0.0116
# AUPRC: 0.1316
# Best threshold: 0.2423
# auc
# Confusion Matrix:
# [[11198  1368]
#  [  674   214]]
# Specificity: 0.8911
# Sensitivity: 0.2410
# Alarm Accuracy: 0.1353
# Accuracy: 0.8482
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12035   531]
#  [  742   146]]
# Specificity: 0.9577
# Sensitivity: 0.1644
# Alarm Accuracy: 0.2157
# Accuracy: 0.9054
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 84---------------------------------------
# Epoch 84, Train Loss: 0.0745
# 整体验证集上的Loss: 0.10177818360641268
# AUROC: 0.7027
# Best threshold: 0.0019
# AUPRC: 0.1734
# Best threshold: 0.0686
# auc
# Confusion Matrix:
# [[9189 3377]
#  [ 362  526]]
# Specificity: 0.7313
# Sensitivity: 0.5923
# Alarm Accuracy: 0.1348
# Accuracy: 0.7221
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11282  1284]
#  [  540   348]]
# Specificity: 0.8978
# Sensitivity: 0.3919
# Alarm Accuracy: 0.2132
# Accuracy: 0.8644
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 85---------------------------------------
# Epoch 85, Train Loss: 0.0732
# 整体验证集上的Loss: 0.0916063145955757
# AUROC: 0.6549
# Best threshold: 0.0013
# AUPRC: 0.1119
# Best threshold: 0.0021
# auc
# Confusion Matrix:
# [[4574 7992]
#  [ 102  786]]
# Specificity: 0.3640
# Sensitivity: 0.8851
# Alarm Accuracy: 0.0895
# Accuracy: 0.3984
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10342  2224]
#  [  583   305]]
# Specificity: 0.8230
# Sensitivity: 0.3435
# Alarm Accuracy: 0.1206
# Accuracy: 0.7914
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 86---------------------------------------
# Epoch 86, Train Loss: 0.0729
# 整体验证集上的Loss: 0.15554659240161048
# AUROC: 0.5986
# Best threshold: 0.0034
# AUPRC: 0.1716
# Best threshold: 0.9407
# auc
# Confusion Matrix:
# [[5838 6728]
#  [ 261  627]]
# Specificity: 0.4646
# Sensitivity: 0.7061
# Alarm Accuracy: 0.0852
# Accuracy: 0.4805
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12006   560]
#  [  728   160]]
# Specificity: 0.9554
# Sensitivity: 0.1802
# Alarm Accuracy: 0.2222
# Accuracy: 0.9043
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 87---------------------------------------
# Epoch 87, Train Loss: 0.0683
# 整体验证集上的Loss: 0.09422655961517051
# AUROC: 0.4461
# Best threshold: 0.0745
# AUPRC: 0.1026
# Best threshold: 0.0831
# auc
# Confusion Matrix:
# [[11736   830]
#  [  706   182]]
# Specificity: 0.9339
# Sensitivity: 0.2050
# Alarm Accuracy: 0.1798
# Accuracy: 0.8858
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11750   816]
#  [  707   181]]
# Specificity: 0.9351
# Sensitivity: 0.2038
# Alarm Accuracy: 0.1815
# Accuracy: 0.8868
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 88---------------------------------------
# Epoch 88, Train Loss: 0.0690
# 整体验证集上的Loss: 0.09694329931165555
# AUROC: 0.7283
# Best threshold: 0.0020
# AUPRC: 0.2009
# Best threshold: 0.2957
# auc
# Confusion Matrix:
# [[9335 3231]
#  [ 317  571]]
# Specificity: 0.7429
# Sensitivity: 0.6430
# Alarm Accuracy: 0.1502
# Accuracy: 0.7363
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12034   532]
#  [  633   255]]
# Specificity: 0.9577
# Sensitivity: 0.2872
# Alarm Accuracy: 0.3240
# Accuracy: 0.9134
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 89---------------------------------------
# Epoch 89, Train Loss: 0.0747
# 整体验证集上的Loss: 0.23700396281086958
# AUROC: 0.5652
# Best threshold: 0.8979
# AUPRC: 0.1751
# Best threshold: 0.9532
# auc
# Confusion Matrix:
# [[10440  2126]
#  [  555   333]]
# Specificity: 0.8308
# Sensitivity: 0.3750
# Alarm Accuracy: 0.1354
# Accuracy: 0.8007
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11436  1130]
#  [  645   243]]
# Specificity: 0.9101
# Sensitivity: 0.2736
# Alarm Accuracy: 0.1770
# Accuracy: 0.8681
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 90---------------------------------------
# Epoch 90, Train Loss: 0.0695
# 整体验证集上的Loss: 0.2181874977818595
# AUROC: 0.4483
# Best threshold: 0.9899
# AUPRC: 0.1265
# Best threshold: 0.9903
# auc
# Confusion Matrix:
# [[12139   427]
#  [  726   162]]
# Specificity: 0.9660
# Sensitivity: 0.1824
# Alarm Accuracy: 0.2750
# Accuracy: 0.9143
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12167   399]
#  [  729   159]]
# Specificity: 0.9682
# Sensitivity: 0.1791
# Alarm Accuracy: 0.2849
# Accuracy: 0.9162
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 91---------------------------------------
# Epoch 91, Train Loss: 0.0681
# 整体验证集上的Loss: 0.19675406046976868
# AUROC: 0.7561
# Best threshold: 0.9434
# AUPRC: 0.3230
# Best threshold: 0.9821
# auc
# Confusion Matrix:
# [[10852  1714]
#  [  385   503]]
# Specificity: 0.8636
# Sensitivity: 0.5664
# Alarm Accuracy: 0.2269
# Accuracy: 0.8440
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11951   615]
#  [  552   336]]
# Specificity: 0.9511
# Sensitivity: 0.3784
# Alarm Accuracy: 0.3533
# Accuracy: 0.9133
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 92---------------------------------------
# Epoch 92, Train Loss: 0.0727
# 整体验证集上的Loss: 0.09470073995152227
# AUROC: 0.7574
# Best threshold: 0.0179
# AUPRC: 0.3238
# Best threshold: 0.2218
# auc
# Confusion Matrix:
# [[9321 3245]
#  [ 281  607]]
# Specificity: 0.7418
# Sensitivity: 0.6836
# Alarm Accuracy: 0.1576
# Accuracy: 0.7379
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12026   540]
#  [  533   355]]
# Specificity: 0.9570
# Sensitivity: 0.3998
# Alarm Accuracy: 0.3966
# Accuracy: 0.9202
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 93---------------------------------------
# Epoch 93, Train Loss: 0.0735
# 整体验证集上的Loss: 0.10005244618701935
# AUROC: 0.7301
# Best threshold: 0.0052
# AUPRC: 0.1714
# Best threshold: 0.0216
# auc
# Confusion Matrix:
# [[10372  2194]
#  [  403   485]]
# Specificity: 0.8254
# Sensitivity: 0.5462
# Alarm Accuracy: 0.1810
# Accuracy: 0.8070
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11036  1530]
#  [  482   406]]
# Specificity: 0.8782
# Sensitivity: 0.4572
# Alarm Accuracy: 0.2097
# Accuracy: 0.8505
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 94---------------------------------------
# Epoch 94, Train Loss: 0.0707
# 整体验证集上的Loss: 0.08894186169398273
# AUROC: 0.4269
# Best threshold: 0.0055
# AUPRC: 0.0600
# Best threshold: 0.0010
# auc
# Confusion Matrix:
# [[10922  1644]
#  [  738   150]]
# Specificity: 0.8692
# Sensitivity: 0.1689
# Alarm Accuracy: 0.0836
# Accuracy: 0.8230
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[  179 12387]
#  [    3   885]]
# Specificity: 0.0142
# Sensitivity: 0.9966
# Alarm Accuracy: 0.0667
# Accuracy: 0.0791
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 95---------------------------------------
# Epoch 95, Train Loss: 0.0735
# 整体验证集上的Loss: 0.09459655075650746
# AUROC: 0.4145
# Best threshold: 0.0524
# AUPRC: 0.0996
# Best threshold: 0.0524
# auc
# Confusion Matrix:
# [[11644   922]
#  [  713   175]]
# Specificity: 0.9266
# Sensitivity: 0.1971
# Alarm Accuracy: 0.1595
# Accuracy: 0.8785
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11644   922]
#  [  713   175]]
# Specificity: 0.9266
# Sensitivity: 0.1971
# Alarm Accuracy: 0.1595
# Accuracy: 0.8785
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 96---------------------------------------
# Epoch 96, Train Loss: 0.0695
# 整体验证集上的Loss: 0.12298716803880974
# AUROC: 0.7653
# Best threshold: 0.0849
# AUPRC: 0.2139
# Best threshold: 0.7402
# auc
# Confusion Matrix:
# [[9600 2966]
#  [ 261  627]]
# Specificity: 0.7640
# Sensitivity: 0.7061
# Alarm Accuracy: 0.1745
# Accuracy: 0.7601
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11772   794]
#  [  550   338]]
# Specificity: 0.9368
# Sensitivity: 0.3806
# Alarm Accuracy: 0.2986
# Accuracy: 0.9001
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 97---------------------------------------
# Epoch 97, Train Loss: 0.0689
# 整体验证集上的Loss: 0.09434439220299545
# AUROC: 0.4049
# Best threshold: 0.0122
# AUPRC: 0.1184
# Best threshold: 0.0540
# auc
# Confusion Matrix:
# [[10684  1882]
#  [  614   274]]
# Specificity: 0.8502
# Sensitivity: 0.3086
# Alarm Accuracy: 0.1271
# Accuracy: 0.8145
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11356  1210]
#  [  673   215]]
# Specificity: 0.9037
# Sensitivity: 0.2421
# Alarm Accuracy: 0.1509
# Accuracy: 0.8600
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 98---------------------------------------
# Epoch 98, Train Loss: 0.0734
# 整体验证集上的Loss: 0.08891801183359711
# AUROC: 0.5640
# Best threshold: 0.0010
# AUPRC: 0.1039
# Best threshold: 0.0014
# auc
# Confusion Matrix:
# [[2604 9962]
#  [  13  875]]
# Specificity: 0.2072
# Sensitivity: 0.9854
# Alarm Accuracy: 0.0807
# Accuracy: 0.2586
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11899   667]
#  [  686   202]]
# Specificity: 0.9469
# Sensitivity: 0.2275
# Alarm Accuracy: 0.2325
# Accuracy: 0.8994
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 99---------------------------------------
# Epoch 99, Train Loss: 0.0696
# 整体验证集上的Loss: 0.19606395844445407
# AUROC: 0.7504
# Best threshold: 0.9477
# AUPRC: 0.2986
# Best threshold: 0.9836
# auc
# Confusion Matrix:
# [[11468  1098]
#  [  449   439]]
# Specificity: 0.9126
# Sensitivity: 0.4944
# Alarm Accuracy: 0.2856
# Accuracy: 0.8850
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[12258   308]
#  [  582   306]]
# Specificity: 0.9755
# Sensitivity: 0.3446
# Alarm Accuracy: 0.4984
# Accuracy: 0.9338
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 100---------------------------------------
# Epoch 100, Train Loss: 0.0710
# 整体验证集上的Loss: 0.09429047924990125
# AUROC: 0.7051
# Best threshold: 0.0047
# AUPRC: 0.1865
# Best threshold: 0.0128
# auc
# Confusion Matrix:
# [[10672  1894]
#  [  423   465]]
# Specificity: 0.8493
# Sensitivity: 0.5236
# Alarm Accuracy: 0.1971
# Accuracy: 0.8278
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11188  1378]
#  [  478   410]]
# Specificity: 0.8903
# Sensitivity: 0.4617
# Alarm Accuracy: 0.2293
# Accuracy: 0.8620
# 混淆矩阵，未归一化
