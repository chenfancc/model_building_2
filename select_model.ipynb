# %%
import os
import json
import pandas as pd

project_dir = 'E:\deeplearning\model_building_2'

# 初始化存储结果的列表
results = []

# 遍历项目目录下的所有文件夹
for folder in os.listdir(project_dir):
    folder_path = os.path.join(project_dir, folder)
    if os.path.isdir(folder_path):
        info_path = os.path.join(folder_path, 'info.json')
        if os.path.exists(info_path):
            # 读取info.json文件
            with open(info_path, 'r') as f:
                data = json.load(f)
                roc_auc_list = data.get('roc_auc_list', [])
                prc_auc_list = data.get('prc_auc_list', [])

                # 确保列表不为空
                if roc_auc_list and prc_auc_list:
                    # 计算roc_auc_list中的最大值及其索引
                    max_roc_auc = max(roc_auc_list)
                    max_roc_index = roc_auc_list.index(max_roc_auc)
                    corresponding_prc_for_max_roc = prc_auc_list[max_roc_index]

                    # 计算prc_auc_list中的最大值及其索引
                    max_prc_auc = max(prc_auc_list)
                    max_prc_index = prc_auc_list.index(max_prc_auc)
                    corresponding_roc_for_max_prc = roc_auc_list[max_prc_index]

                    # 计算roc_auc_list和prc_auc_list乘积的最大值及其索引
                    auc_prc_product_list = [roc * prc for roc, prc in zip(roc_auc_list, prc_auc_list)]
                    max_product = max(auc_prc_product_list)
                    max_product_index = auc_prc_product_list.index(max_product)
                    roc_at_max_product = roc_auc_list[max_product_index]
                    prc_at_max_product = prc_auc_list[max_product_index]
                    
                    # 计算roc_auc_list和prc_auc_list和的最大值及其索引
                    auc_prc_plus_list = [(roc + prc) for roc, prc in zip(roc_auc_list, prc_auc_list)]
                    max_plus = max(auc_prc_plus_list)
                    max_plus_index = auc_prc_plus_list.index(max_plus)
                    roc_at_max_plus = roc_auc_list[max_plus_index]
                    prc_at_max_plus = prc_auc_list[max_plus_index]

                    # 存储结果
                    results.append([
                        folder, 
                        max_roc_auc, 
                        max_roc_index + 1,  # 转换为从1开始的索引
                        corresponding_prc_for_max_roc, 
                        max_prc_auc, 
                        max_prc_index + 1,  # 转换为从1开始的索引
                        corresponding_roc_for_max_prc,
                        max_product,
                        roc_at_max_product,
                        prc_at_max_product,
                        max_product_index + 1,  # 转换为从1开始的索引
                        max_plus,
                        roc_at_max_plus,
                        prc_at_max_plus,
                        max_plus_index + 1  # 转换为从1开始的索引
                    ])

# 转换结果为DataFrame并输出表格
df = pd.DataFrame(results, columns=[
    'Folder', 
    'Max ROC AUC', 
    'ROC Index', 
    'PRC at Max ROC', 
    'Max PRC AUC', 
    'PRC Index', 
    'ROC at Max PRC',
    'Max AUC*PRC Product',
    'ROC at Max Product',
    'PRC at Max Product',
    'Product Index',
    'Max AUC+PRC Plus',
    'ROC at Max Plus',
    'PRC at Max Plus',
    'Plus Index'
])

# %%
# 新增第一列，为Max ROC AUC与PRC at Max ROC的乘积
df['Max ROC'] = df['Max ROC AUC'] * df['PRC at Max ROC']

# 新增第二列，为Max PRC AUC与ROC at Max PRC的乘积
df['Max PRC'] = df['Max PRC AUC'] * df['ROC at Max PRC']

# %%
df
# Out:
#                                                Folder  Max ROC AUC  ROC Index  \
# 0                                              00test     4.000000          4
# 1              BiLSTM_BN_3layers_model_undersample_20     0.782533          9
# 2    BiLSTM_BN_3layers_model_undersample_FocalLoss_20     0.767494         29
# 3    BiLSTM_BN_3layers_model_undersample_FocalLoss_24     0.772673         18
# 4    BiLSTM_BN_3layers_model_undersample_FocalLoss_30     0.767629         22
# 5    BiLSTM_BN_3layers_model_undersample_FocalLoss_36     0.757575         24
# 6    BiLSTM_BN_3layers_model_undersample_FocalLoss_48     0.737030         25
# 7                  BiLSTM_BN_model_smote_FocalLoss_20     0.763655          1
# 8                BiLSTM_BN_model_smote_FocalLoss_2_20     0.758662          2
# 9                      BiLSTM_BN_model_undersample_20     0.779339         11
# 10           BiLSTM_BN_model_undersample_FocalLoss_20     0.765978         27
# 11           BiLSTM_BN_model_undersample_FocalLoss_24     0.775299         55
# 12           BiLSTM_BN_model_undersample_FocalLoss_30     0.757834         51
# 13           BiLSTM_BN_model_undersample_FocalLoss_36     0.753664         59
# 14           BiLSTM_BN_model_undersample_FocalLoss_48     0.728774         63
# 15              BiLSTM_BN_Resnet_model_undersample_20     0.775847          8
# 16    BiLSTM_BN_Resnet_model_undersample_FocalLoss_20     0.769434         49
# 17    BiLSTM_BN_Resnet_model_undersample_FocalLoss_24     0.766248         55
# 18    BiLSTM_BN_Resnet_model_undersample_FocalLoss_30     0.751537         19
# 19    BiLSTM_BN_Resnet_model_undersample_FocalLoss_36     0.747266          9
# 20    BiLSTM_BN_Resnet_model_undersample_FocalLoss_48     0.728906         20
# 21                              BiLSTM_model_smote_20     0.785985          1
# 22                    BiLSTM_model_smote_FocalLoss_20     0.751812          9
# 23                  BiLSTM_model_smote_FocalLoss_2_20     0.735016          5
# 24              BiLSTM_model_undersample_FocalLoss_20     0.717531        100
# 25              BiLSTM_model_undersample_FocalLoss_24     0.704981        100
# 26              BiLSTM_model_undersample_FocalLoss_30     0.700806         99
# 27              BiLSTM_model_undersample_FocalLoss_36     0.700482         92
# 28              BiLSTM_model_undersample_FocalLoss_48     0.661656         19
# 29    Zhongda_2_BiLSTM_BN_model_undersample_FocalLoss     0.845672        123
# 30  Zhongda_3_BiLSTM_BN_larger_model_origin_FocalLoss     0.818089         26
# 31  Zhongda_3_BiLSTM_BN_larger_model_undersample_F...     0.828600         78
# 32         Zhongda_3_BiLSTM_BN_model_origin_FocalLoss     0.813387         63
# 33    Zhongda_3_BiLSTM_BN_model_undersample_FocalLoss     0.841271         48
# 34  Zhongda_BiLSTM_BN_3layers_model_undersample_Fo...     0.825779         31
# 35           Zhongda_BiLSTM_BN_model_origin_FocalLoss     0.823325         52
# 36            Zhongda_BiLSTM_BN_model_smote_FocalLoss     0.804396          2
# 37      Zhongda_BiLSTM_BN_model_undersample_FocalLoss     0.835946        100
# 38     Zhongda_BiLSTM_BN_Resnet_model_smote_FocalLoss     0.842693          1
# 39  Zhongda_BiLSTM_BN_Resnet_model_undersample_Foc...     0.813133         85
# 40               Zhongda_BiLSTM_model_smote_FocalLoss     0.836127          8
# 41         Zhongda_BiLSTM_model_undersample_FocalLoss     0.804092         62
# 42         Zhongda_GRU_BN_model_undersample_FocalLoss     0.823384          7
#
#     PRC at Max ROC  Max PRC AUC  PRC Index  ROC at Max PRC  \
# 0         3.000000     3.000000          4        4.000000
# 1         0.161367     0.192848          8        0.773934
# 2         0.174521     0.177634         21        0.762646
# 3         0.189968     0.196024         71        0.759101
# 4         0.197300     0.202080         38        0.748110
# 5         0.206767     0.214385         30        0.749915
# 6         0.213478     0.220685         31        0.725487
# 7         0.175363     0.183953          2        0.759725
# 8         0.172222     0.178471          3        0.750710
# 9         0.177220     0.193572          8        0.777850
# 10        0.173588     0.176762        100        0.764310
# 11        0.192395     0.197132         92        0.773446
# 12        0.186853     0.188892         97        0.753147
# 13        0.216009     0.217543         72        0.750285
# 14        0.237466     0.243482         83        0.724391
# 15        0.164992     0.180766          7        0.769052
# 16        0.177675     0.179893         86        0.762319
# 17        0.198437     0.199029         51        0.764168
# 18        0.193117     0.200440         88        0.743385
# 19        0.206872     0.211530         29        0.736003
# 20        0.222058     0.224538         39        0.720403
# 21        0.212092     0.212092          1        0.785985
# 22        0.161088     0.167603          2        0.718257
# 23        0.163728     0.172528          3        0.721793
# 24        0.166459     0.166459        100        0.717531
# 25        0.180760     0.181859         98        0.704839
# 26        0.190456     0.209128         25        0.609407
# 27        0.216441     0.218344         43        0.696384
# 28        0.188378     0.205404         54        0.659670
# 29        0.114010     0.122092        487        0.829600
# 30        0.116380     0.119456         35        0.797503
# 31        0.094914     0.109940        172        0.794182
# 32        0.101341     0.103641        807        0.676275
# 33        0.103455     0.123256        226        0.819961
# 34        0.107778     0.115777         15        0.818031
# 35        0.103069     0.125892         35        0.780718
# 36        0.131025     0.131025          2        0.804396
# 37        0.102417     0.105377         46        0.825074
# 38        0.126247     0.130947          3        0.782819
# 39        0.111798     0.116140         78        0.810737
# 40        0.094438     0.119633         17        0.817238
# 41        0.056643     0.061537         20        0.794734
# 42        0.095779     0.099319          8        0.809760
#
#     Max AUC*PRC Product  ROC at Max Product  PRC at Max Product  \
# 0             12.000000            4.000000            3.000000
# 1              0.149252            0.773934            0.192848
# 2              0.136120            0.766739            0.177531
# 3              0.148802            0.759101            0.196024
# 4              0.151453            0.767629            0.197300
# 5              0.160771            0.749915            0.214385
# 6              0.160104            0.725487            0.220685
# 7              0.139754            0.759725            0.183953
# 8              0.133980            0.750710            0.178471
# 9              0.150570            0.777850            0.193572
# 10             0.135101            0.764310            0.176762
# 11             0.152471            0.773446            0.197132
# 12             0.142264            0.753147            0.188892
# 13             0.163413            0.753461            0.216884
# 14             0.176376            0.724391            0.243482
# 15             0.139019            0.769052            0.180766
# 16             0.137136            0.762319            0.179893
# 17             0.152091            0.764168            0.199029
# 18             0.149004            0.743385            0.200440
# 19             0.156873            0.746501            0.210144
# 20             0.162354            0.724862            0.223979
# 21             0.166701            0.785985            0.212092
# 22             0.121108            0.751812            0.161088
# 23             0.124530            0.721793            0.172528
# 24             0.119439            0.717531            0.166459
# 25             0.128182            0.704839            0.181859
# 26             0.134362            0.699598            0.192056
# 27             0.152152            0.700203            0.217297
# 28             0.135499            0.659670            0.205404
# 29             0.101287            0.829600            0.122092
# 30             0.095266            0.797503            0.119456
# 31             0.089566            0.823855            0.108716
# 32             0.082430            0.813387            0.101341
# 33             0.101676            0.825690            0.123141
# 34             0.094709            0.818031            0.115777
# 35             0.098286            0.780718            0.125892
# 36             0.105396            0.804396            0.131025
# 37             0.086944            0.825074            0.105377
# 38             0.106388            0.842693            0.126247
# 39             0.094159            0.810737            0.116140
# 40             0.097769            0.817238            0.119633
# 41             0.048905            0.794734            0.061537
# 42             0.080425            0.809760            0.099319
#
#     Product Index  Max AUC+PRC Plus  ROC at Max Plus  PRC at Max Plus  \
# 0               4          7.000000         4.000000         3.000000
# 1               8          0.966782         0.773934         0.192848
# 2              12          0.944269         0.766739         0.177531
# 3              71          0.962641         0.772673         0.189968
# 4              22          0.964929         0.767629         0.197300
# 5              30          0.964342         0.757575         0.206767
# 6              31          0.950508         0.737030         0.213478
# 7               2          0.943677         0.759725         0.183953
# 8               3          0.930884         0.758662         0.172222
# 9               8          0.971422         0.777850         0.193572
# 10            100          0.941422         0.764916         0.176506
# 11             92          0.970579         0.773446         0.197132
# 12             97          0.944686         0.757834         0.186853
# 13             74          0.970344         0.753461         0.216884
# 14             83          0.969646         0.728428         0.241218
# 15              7          0.949819         0.769052         0.180766
# 16             86          0.947109         0.769434         0.177675
# 17             51          0.964685         0.766248         0.198437
# 18             88          0.945286         0.746483         0.198803
# 19             12          0.956646         0.746501         0.210144
# 20             24          0.950970         0.727944         0.223026
# 21              1          0.998077         0.785985         0.212092
# 22              9          0.912899         0.751812         0.161088
# 23              3          0.898744         0.735016         0.163728
# 24            100          0.883990         0.717531         0.166459
# 25             98          0.886699         0.704839         0.181859
# 26             93          0.891675         0.699957         0.191718
# 27            100          0.917501         0.700203         0.217297
# 28             54          0.865073         0.659670         0.205404
# 29            487          0.959682         0.845672         0.114010
# 30             35          0.934469         0.818089         0.116380
# 31             93          0.932571         0.823855         0.108716
# 32             63          0.914728         0.813387         0.101341
# 33            236          0.953832         0.836267         0.117565
# 34             15          0.936858         0.824569         0.112289
# 35             35          0.926393         0.823325         0.103069
# 36              2          0.935421         0.804396         0.131025
# 37             46          0.938363         0.835946         0.102417
# 38              1          0.968940         0.842693         0.126247
# 39             78          0.926878         0.810737         0.116140
# 40             17          0.936871         0.817238         0.119633
# 41             20          0.860735         0.804092         0.056643
# 42              8          0.919163         0.823384         0.095779
#
#     Plus Index
# 0            4
# 1            8
# 2           12
# 3           18
# 4           22
# 5           24
# 6           25
# 7            2
# 8            2
# 9            8
# 10          91
# 11          92
# 12          51
# 13          74
# 14          94
# 15           7
# 16          49
# 17          55
# 18          93
# 19          12
# 20          29
# 21           1
# 22           9
# 23           5
# 24         100
# 25          98
# 26          94
# 27         100
# 28          54
# 29         123
# 30          26
# 31          93
# 32          63
# 33          97
# 34          27
# 35          52
# 36           2
# 37         100
# 38           1
# 39          78
# 40          17
# 41          62
# 42           7

# %%
# 如果需要保存为CSV文件，可以使用以下代码
output_path = os.path.join(project_dir, 'auc_results.csv')
df.to_csv(output_path, index=False)
