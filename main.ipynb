# %%
from function import *
from model_trainer import TrainModel
import numpy as np
from model import *
from function import plot_info

BATCH_SIZE = 512
EPOCH = 3
LR = 0.01 # 5e-6
GAMMA = 0.95
STEP_SIZE = 20  # 每隔多少个 epoch 衰减一次学习率
DECAY = 1e-4
DEVICE = "cuda"
SEED = 42
ALPHA_LOSS = 1
GAMMA_LOSS = 3

hyperparameters = {
    "BATCH_SIZE": BATCH_SIZE,
    "EPOCH": EPOCH,
    "LEARNING_RATE": LR,
    "GAMMA": GAMMA,
    "STEP_SIZE": STEP_SIZE,
    "DECAY": DECAY,
    "device": DEVICE,
    "SEED": SEED,
    "ALPHA_LOSS": ALPHA_LOSS,
    "GAMMA_LOSS": GAMMA_LOSS
}

# %%
if __name__ == '__main__':
    # 设置随机种子
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    for SAMPLE_METHOD in ["undersample"]:
        for model in [BiLSTM]:
            tensor_direction = f'E:\deeplearning\Zhongda\zyy_tensor.pth'
            train_dataloader, val_dataloader, test_dataloader = main_data_loader(tensor_direction, SAMPLE_METHOD, BATCH_SIZE)
            model_name = f"ZYY_{model.__name__}_model_{SAMPLE_METHOD}_FocalLoss_{EPOCH}_{LR}"
            loss_f = FocalLoss(ALPHA_LOSS, GAMMA_LOSS)
            trainer = TrainModel(model_name, model, hyperparameters, train_dataloader, val_dataloader,
                                 criterion_class=loss_f, root_dir='ZYY')
            info = trainer.train()
            trainer.save_model()
            plot_info(info, model_name, root_dir='ZYY')
# Out:
# ---------------------------------------Epoch: 1---------------------------------------
# Epoch 1, Train Loss: 0.0769
# 整体验证集上的Loss: 0.10601055158998349
# AUROC: 0.6569
# Best threshold: 0.1145
# AUPRC: 0.1318
# Best threshold: 0.1524
# auc
# Confusion Matrix:
# [[8605 3961]
#  [ 402  486]]
# Specificity: 0.6848
# Sensitivity: 0.5473
# Alarm Accuracy: 0.1093
# Accuracy: 0.6757
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11566  1000]
#  [  661   227]]
# Specificity: 0.9204
# Sensitivity: 0.2556
# Alarm Accuracy: 0.1850
# Accuracy: 0.8765
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 2---------------------------------------
# Epoch 2, Train Loss: 0.0764
# 整体验证集上的Loss: 0.14667340015308947
# AUROC: 0.5629
# Best threshold: 0.3877
# AUPRC: 0.1145
# Best threshold: 0.3969
# auc
# Confusion Matrix:
# [[10668  1898]
#  [  588   300]]
# Specificity: 0.8490
# Sensitivity: 0.3378
# Alarm Accuracy: 0.1365
# Accuracy: 0.8152
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10904  1662]
#  [  610   278]]
# Specificity: 0.8677
# Sensitivity: 0.3131
# Alarm Accuracy: 0.1433
# Accuracy: 0.8311
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 3---------------------------------------
# Epoch 3, Train Loss: 0.0766
# 整体验证集上的Loss: 0.3077928562456061
# AUROC: 0.5664
# Best threshold: 0.7994
# AUPRC: 0.1202
# Best threshold: 0.8240
# auc
# Confusion Matrix:
# [[10560  2006]
#  [  579   309]]
# Specificity: 0.8404
# Sensitivity: 0.3480
# Alarm Accuracy: 0.1335
# Accuracy: 0.8079
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11114  1452]
#  [  632   256]]
# Specificity: 0.8845
# Sensitivity: 0.2883
# Alarm Accuracy: 0.1499
# Accuracy: 0.8451
# 混淆矩阵，未归一化

# %%
if __name__ == '__main__':
    for SAMPLE_METHOD in ["undersample"]:
        for model in [BiLSTM, BiLSTM_BN]:
            # 设置随机种子
            np.random.seed(SEED)
            torch.manual_seed(SEED)
            tensor_direction = f'E:\deeplearning\Zhongda\zyy_tensor.pth'
            train_dataloader, val_dataloader, test_dataloader = main_data_loader(tensor_direction, SAMPLE_METHOD, BATCH_SIZE)
            model_name = f"ZYY_{model.__name__}_model_{SAMPLE_METHOD}_FocalLoss_{EPOCH}_{LR}"
            loss_f = FocalLoss(ALPHA_LOSS, GAMMA_LOSS)
            trainer = TrainModel(model_name, model, hyperparameters, train_dataloader, val_dataloader,
                                 criterion_class=loss_f, root_dir='ZYY')
            info = trainer.train()
            trainer.save_model()
            plot_info(info, model_name, root_dir='ZYY')
# Out:
# ---------------------------------------Epoch: 1---------------------------------------
# Epoch 1, Train Loss: 0.0769
# 整体验证集上的Loss: 0.10601055158998349
# AUROC: 0.6569
# Best threshold: 0.1145
# AUPRC: 0.1318
# Best threshold: 0.1524
# auc
# Confusion Matrix:
# [[8605 3961]
#  [ 402  486]]
# Specificity: 0.6848
# Sensitivity: 0.5473
# Alarm Accuracy: 0.1093
# Accuracy: 0.6757
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11566  1000]
#  [  661   227]]
# Specificity: 0.9204
# Sensitivity: 0.2556
# Alarm Accuracy: 0.1850
# Accuracy: 0.8765
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 2---------------------------------------
# Epoch 2, Train Loss: 0.0764
# 整体验证集上的Loss: 0.14667340015308947
# AUROC: 0.5629
# Best threshold: 0.3877
# AUPRC: 0.1145
# Best threshold: 0.3969
# auc
# Confusion Matrix:
# [[10668  1898]
#  [  588   300]]
# Specificity: 0.8490
# Sensitivity: 0.3378
# Alarm Accuracy: 0.1365
# Accuracy: 0.8152
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10904  1662]
#  [  610   278]]
# Specificity: 0.8677
# Sensitivity: 0.3131
# Alarm Accuracy: 0.1433
# Accuracy: 0.8311
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 3---------------------------------------
# Epoch 3, Train Loss: 0.0766
# 整体验证集上的Loss: 0.3077928562456061
# AUROC: 0.5664
# Best threshold: 0.7994
# AUPRC: 0.1202
# Best threshold: 0.8240
# auc
# Confusion Matrix:
# [[10560  2006]
#  [  579   309]]
# Specificity: 0.8404
# Sensitivity: 0.3480
# Alarm Accuracy: 0.1335
# Accuracy: 0.8079
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11114  1452]
#  [  632   256]]
# Specificity: 0.8845
# Sensitivity: 0.2883
# Alarm Accuracy: 0.1499
# Accuracy: 0.8451
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 1---------------------------------------
# Epoch 1, Train Loss: 0.0858
# 整体验证集上的Loss: 0.14782243973064424
# AUROC: 0.4809
# Best threshold: 0.2867
# AUPRC: 0.0954
# Best threshold: 0.2868
# auc
# Confusion Matrix:
# [[11220  1346]
#  [  662   226]]
# Specificity: 0.8929
# Sensitivity: 0.2545
# Alarm Accuracy: 0.1438
# Accuracy: 0.8508
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11283  1283]
#  [  667   221]]
# Specificity: 0.8979
# Sensitivity: 0.2489
# Alarm Accuracy: 0.1469
# Accuracy: 0.8551
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 2---------------------------------------
# Epoch 2, Train Loss: 0.0759
# 整体验证集上的Loss: 0.09437102609699745
# AUROC: 0.5674
# Best threshold: 0.0501
# AUPRC: 0.0996
# Best threshold: 0.0563
# auc
# Confusion Matrix:
# [[9797 2769]
#  [ 569  319]]
# Specificity: 0.7796
# Sensitivity: 0.3592
# Alarm Accuracy: 0.1033
# Accuracy: 0.7519
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10704  1862]
#  [  636   252]]
# Specificity: 0.8518
# Sensitivity: 0.2838
# Alarm Accuracy: 0.1192
# Accuracy: 0.8143
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 3---------------------------------------
# Epoch 3, Train Loss: 0.0746
# 整体验证集上的Loss: 0.09307185787230951
# AUROC: 0.7312
# Best threshold: 0.0103
# AUPRC: 0.1550
# Best threshold: 0.0107
# auc
# Confusion Matrix:
# [[7058 5508]
#  [  64  824]]
# Specificity: 0.5617
# Sensitivity: 0.9279
# Alarm Accuracy: 0.1301
# Accuracy: 0.5858
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[7643 4923]
#  [ 129  759]]
# Specificity: 0.6082
# Sensitivity: 0.8547
# Alarm Accuracy: 0.1336
# Accuracy: 0.6245
# 混淆矩阵，未归一化

# %%
if __name__ == '__main__':
    # 设置随机种子
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    for SAMPLE_METHOD in ["undersample"]:
        for model in [BiLSTM_BN]:
            tensor_direction = f'E:\deeplearning\Zhongda\zyy_tensor.pth'
            train_dataloader, val_dataloader, test_dataloader = main_data_loader(tensor_direction, SAMPLE_METHOD, BATCH_SIZE)
            model_name = f"ZYY_{model.__name__}_model_{SAMPLE_METHOD}_FocalLoss_{EPOCH}_{LR}"
            loss_f = FocalLoss(ALPHA_LOSS, GAMMA_LOSS)
            trainer = TrainModel(model_name, model, hyperparameters, train_dataloader, val_dataloader,
                                 criterion_class=loss_f, root_dir='ZYY')
            info = trainer.train()
            trainer.save_model()
            plot_info(info, model_name, root_dir='ZYY')
# Out:
# ---------------------------------------Epoch: 1---------------------------------------
# Epoch 1, Train Loss: 0.0858
# 整体验证集上的Loss: 0.14782243973064424
# AUROC: 0.4809
# Best threshold: 0.2867
# AUPRC: 0.0954
# Best threshold: 0.2868
# auc
# Confusion Matrix:
# [[11220  1346]
#  [  662   226]]
# Specificity: 0.8929
# Sensitivity: 0.2545
# Alarm Accuracy: 0.1438
# Accuracy: 0.8508
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[11283  1283]
#  [  667   221]]
# Specificity: 0.8979
# Sensitivity: 0.2489
# Alarm Accuracy: 0.1469
# Accuracy: 0.8551
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 2---------------------------------------
# Epoch 2, Train Loss: 0.0759
# 整体验证集上的Loss: 0.09437102609699745
# AUROC: 0.5674
# Best threshold: 0.0501
# AUPRC: 0.0996
# Best threshold: 0.0563
# auc
# Confusion Matrix:
# [[9797 2769]
#  [ 569  319]]
# Specificity: 0.7796
# Sensitivity: 0.3592
# Alarm Accuracy: 0.1033
# Accuracy: 0.7519
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[10704  1862]
#  [  636   252]]
# Specificity: 0.8518
# Sensitivity: 0.2838
# Alarm Accuracy: 0.1192
# Accuracy: 0.8143
# 混淆矩阵，未归一化
# ---------------------------------------Epoch: 3---------------------------------------
# Epoch 3, Train Loss: 0.0746
# 整体验证集上的Loss: 0.09307185787230951
# AUROC: 0.7312
# Best threshold: 0.0103
# AUPRC: 0.1550
# Best threshold: 0.0107
# auc
# Confusion Matrix:
# [[7058 5508]
#  [  64  824]]
# Specificity: 0.5617
# Sensitivity: 0.9279
# Alarm Accuracy: 0.1301
# Accuracy: 0.5858
# 混淆矩阵，未归一化
# prc
# Confusion Matrix:
# [[7643 4923]
#  [ 129  759]]
# Specificity: 0.6082
# Sensitivity: 0.8547
# Alarm Accuracy: 0.1336
# Accuracy: 0.6245
# 混淆矩阵，未归一化
